# %% [markdown]
# PHARMASTATE WEB SCRAPPING

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time

def clean_text(text):
    return re.sub(r'[^\x00-\x7F]+', '', text).strip()

def scrape_pharmastate_full(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    r = requests.get(url, headers=headers, timeout=10)
    soup = BeautifulSoup(r.content, 'html.parser')

    # Course Name
    course_name_div = soup.find('div', class_='elementor-widget-etlms-course-title')
    course_name = clean_text(course_name_div.get_text(strip=True)) if course_name_div else ''

    # About Course
    desc_div = soup.find('div', class_='tutor-single-course-segment etlms-course-description')
    about_course = ''
    if desc_div:
        raw_text = desc_div.get_text(separator=' ', strip=True)
        stop_keywords = [
            'what will you learn', 'why should you attend', 'What will your learn',
            'who should enroll', 'What will I learn ', 'language:',
            'objective of sop', 'how to download course certificate'
        ]
        stop_index = len(raw_text)
        for keyword in stop_keywords:
            idx = raw_text.lower().find(keyword)
            if idx != -1 and idx < stop_index:
                stop_index = idx
        about_course = raw_text[:stop_index].strip()
        if about_course.lower().startswith("description"):
            about_course = about_course[len("description"):].strip(": ").strip()

    # What I will learn
    what_learn = ''
    learn_ul = soup.find('ul', class_='etlms-course-widget-list-items')
    if learn_ul:
        items = learn_ul.find_all('span', class_='tutor-list-label')
        what_learn = '\n'.join(item.get_text(strip=True) for item in items)

    if not what_learn and desc_div:
        for tag in desc_div.find_all(['strong', 'h3', 'h2', 'b', 'p']):
            if 'what will you learn' in tag.get_text(strip=True).lower():
                next_node = tag.find_next_sibling()
                result = []
                while next_node and next_node.name in ['ul', 'p']:
                    text = next_node.get_text(strip=True)
                    if text:
                        result.append(text)
                    next_node = next_node.find_next_sibling()
                what_learn = '\n'.join(result)
                break

    for phrase in ['Language: English', 'How to Download Course certificate: Watch Video']:
        what_learn = what_learn.replace(phrase, '').strip()

    # Prices
    price_spans = soup.find_all('span', class_='woocommerce-Price-amount')
    prices = [span.find('bdi').get_text(strip=True).replace("₹", "").replace(",", "").strip()
              for span in price_spans if span.find('bdi')]
    selling_price, offer_price = '', ''
    if len(prices) >= 2:
        selling_price, offer_price = prices[0], prices[1]
    elif len(prices) == 1:
        offer_price = prices[0]
        selling_price = prices[0]
    if offer_price in ['0', '0.00', '', None] and selling_price:
        offer_price = selling_price

    # Duration
    duration_span = soup.find('span', class_='tutor-meta-value tutor-color-secondary tutor-mr-4')
    duration = duration_span.get_text(strip=True) if duration_span else ''
    duration = duration.replace("hours", "Hours").replace("minutes", "Minutes")

    # Duration Time & Rounded
    parts = soup.find_all('span', class_='tutor-meta-level')
    if len(parts) >= 2:
        h = int(parts[0].get_text(strip=True))
        m = int(parts[1].get_text(strip=True))
        duration_time = f"{h:02d}:{m:02d}"
        rounded = str(h) if m < 15 else str(h + 0.5 if m < 45 else h + 1)
    elif len(parts) == 1:
        h, m = 0, int(parts[0].get_text(strip=True))
        duration_time = str(m)
        rounded = str(m)
    else:
        duration_time = ''
        rounded = ''

    # Fee Structure
    fee_structure = (
        f"{offer_price} \n -All other fees remain unchanged\n"
        "-Education loans are available through leading banks and NBFCs.\n"
        
    ) if offer_price else (
        "-All other fees remain unchanged\n"
        "-Education loans are available through leading banks and NBFCs.\n"
        
    )

    # Language
    language = ''
    for p in soup.find_all('p'):
        if 'Language:' in p.get_text():
            language = p.get_text().replace("Language:", "").strip()
            break

    # Course Level
    course_level_span = soup.find('span', class_='tutor-fs-7 tutor-fw-medium tutor-color-black etlms-enrolled-label-value')
    course_level = course_level_span.get_text(strip=True) if course_level_span else ''
    if course_level.lower() == "all levels":
        course_level = "Beginner"

    # Certificate
    certificate = ''
    spans = soup.find_all('span', class_='tutor-fs-7 tutor-fw-medium tutor-color-black etlms-enrolled-label-value')
    for span in spans:
        text = span.get_text(strip=True)
        if 'certificate' in text.lower():
            certificate = text
            break

    # Certificate Image
    cert_img_tag = soup.find('img', alt='selected template')
    certificate_image = cert_img_tag['src'] if cert_img_tag and 'src' in cert_img_tag.attrs else ''

    # Who should take it
    who_should_take_it = ''
    for h3 in soup.find_all('h3'):
        if 'Target Audience' in h3.get_text():
            ul = h3.find_next_sibling('ul')
            if ul:
                who_should_take_it = ' \n '.join(li.get_text(strip=True) for li in ul.find_all('li'))

    # Educator
    educator_tags = soup.find_all('a', class_='tutor-instructor-name tutor-fs-6 tutor-fw-bold tutor-color-black')
    educators = [tag.get_text(strip=True) for tag in educator_tags if tag.get_text(strip=True).lower() != "pharmastate academy"]
    educator = ', '.join(educators)

    # Course Syllabus
    curriculum = []
    modules = soup.find_all('div', class_='tutor-accordion-item')
    for module in modules:
        module_title_tag = module.find('h4', class_='tutor-accordion-item-header')
        module_title = clean_text(module_title_tag.get_text(strip=True)) if module_title_tag else "Untitled Module"
        lesson_tags = module.find_all('li', class_='tutor-course-content-list-item')
        lesson_list = [f"- {clean_text(lesson.find('h5').get_text(strip=True))}" for lesson in lesson_tags if lesson.find('h5')]
        curriculum.append(f"🔸 {module_title}\n" + '\n'.join(lesson_list))

    course_syllabus = '\n\n'.join(curriculum)

    return {
        'Course Name': course_name,
        'Course Link': url,
        'About Course': about_course,
        'Selling Price': selling_price,
        'Offer Price': offer_price,
        'Duration': duration,
        'Duration Time': duration_time,
        'Rounded Duration': rounded,
        'Fee Structure': fee_structure,
        'Language': language,
        'Course Level': course_level,
        'Certificate': certificate,
        'Certificate Image': certificate_image,
        'Educator': educator,
        'Who should take it': who_should_take_it,
        'What I will learn': what_learn,
        'Course Syllabus': course_syllabus
    }

# === MAIN ===
if __name__ == "__main__":
    input_path = "C:\\Users\\taslim.siddiqui\\Downloads\\Courselink for pharma state cpp.xlsx"
    output_path = "C:\\Users\\taslim.siddiqui\\Downloads\\pharmastate_course_combined_FINAL_10_09_2025.xlsx"

    df_links = pd.read_excel(input_path)
    if 'Course Link' not in df_links.columns:
        raise ValueError("❌ 'Course Link' column not found in Excel file.")

    urls = df_links['Course Link'].dropna().unique()
    all_data = []

    for i, url in enumerate(urls):
        print(f"🔄 Scraping ({i+1}/{len(urls)}): {url}")
        try:
            data = scrape_pharmastate_full(url)
        except Exception as e:
            print(f"❌ Error scraping {url}: {e}")
            data = {
                'Course Name': '', 'Course Link': url, 'About Course': '',
                'Selling Price': '', 'Offer Price': '', 'Duration': '',
                'Duration Time': '', 'Rounded Duration': '', 'Fee Structure': '',
                'Language': '', 'Course Level': '', 'Certificate': '',
                'Certificate Image': '', 'Educator': '', 'Who should take it': '',
                'What I will learn': '', 'Course Syllabus': ''
            }
        all_data.append(data)
        time.sleep(1)

    df_out = pd.DataFrame(all_data)
    df_out.to_excel(output_path, index=False)
    print(f"\n✅ All courses saved to Excel: {output_path}")
# Out:
# 🔄 Scraping (1/388): https://pharmastate.academy/courses/5-essentials-tips-to-generate-prescription/
# 🔄 Scraping (2/388): https://pharmastate.academy/courses/dealing-with-pharma-industrial-emergency-conditions-safety-guidelines/
# 🔄 Scraping (3/388): https://pharmastate.academy/courses/sop-for-determination-of-shelf-life-of-solution-in-laboratory/
# 🔄 Scraping (4/388): https://pharmastate.academy/courses/trending-of-breakdowns-in-equipment/
# 🔄 Scraping (5/388): https://pharmastate.academy/courses/incident-investigation/
# 🔄 Scraping (6/388): https://pharmastate.academy/courses/sop-for-determination-of-leak-test-of-packed-material/
# 🔄 Scraping (7/388): https://pharmastate.academy/courses/liquid-particulate-measuring-system/
# 🔄 Scraping (8/388): https://pharmastate.academy/courses/how-to-define-incident-description/
# 🔄 Scraping (9/388): https://pharmastate.academy/courses/human-error-reduction/
# 🔄 Scraping (10/388): https://pharmastate.academy/courses/effective-sop/
# 🔄 Scraping (11/388): https://pharmastate.academy/courses/how-to-respond-to-audit-observation/
# 🔄 Scraping (12/388): https://pharmastate.academy/courses/hvac-system-validation-tests/
# 🔄 Scraping (13/388): https://pharmastate.academy/courses/sop-of-control-sample-management/
# 🔄 Scraping (14/388): https://pharmastate.academy/courses/visual-inspection-in-injectables/
# 🔄 Scraping (15/388): https://pharmastate.academy/courses/anger-control-pills-of-motivation/
# 🔄 Scraping (16/388): https://pharmastate.academy/courses/hope-and-self-belief-for-pharma-professionals/
# 🔄 Scraping (17/388): https://pharmastate.academy/courses/root-cause-analysis/
# 🔄 Scraping (18/388): https://pharmastate.academy/courses/why-root-cause-not-identified-in-an-investigation/
# 🔄 Scraping (19/388): https://pharmastate.academy/courses/quality-responsibility/
# 🔄 Scraping (20/388): https://pharmastate.academy/courses/audit-question-answer/
# 🔄 Scraping (21/388): https://pharmastate.academy/courses/mini-bite-5-johari-window-and-leadership-skills/
# 🔄 Scraping (22/388): https://pharmastate.academy/courses/concept-of-dissolution/
# 🔄 Scraping (23/388): https://pharmastate.academy/courses/primary-secondary-sales-in-pharma-industry/
# 🔄 Scraping (24/388): https://pharmastate.academy/courses/media-fill-failure-investigation/
# 🔄 Scraping (25/388): https://pharmastate.academy/courses/presenting-documents-during-inspection-in-pharma/
# 🔄 Scraping (26/388): https://pharmastate.academy/courses/how-to-prepare-warehouse-for-usfda-inspection/
# 🔄 Scraping (27/388): https://pharmastate.academy/courses/sop-for-quality-management-system-documentation/
# 🔄 Scraping (28/388): https://pharmastate.academy/courses/sampling-and-release-of-material/
# 🔄 Scraping (29/388): https://pharmastate.academy/courses/alcoa-in-pharmaceutical-industry/
# 🔄 Scraping (30/388): https://pharmastate.academy/courses/audit-room-regulatory-inspection/
# 🔄 Scraping (31/388): https://pharmastate.academy/courses/oral-liquid-formulations/
# 🔄 Scraping (32/388): https://pharmastate.academy/courses/principles-of-gmp/
# 🔄 Scraping (33/388): https://pharmastate.academy/courses/sop-for-vendor-qualification-approval-in-pharmaceutical-industry/
# 🔄 Scraping (34/388): https://pharmastate.academy/courses/problem-solving/
# 🔄 Scraping (35/388): https://pharmastate.academy/courses/6m-investigation-method-for-pharma/
# 🔄 Scraping (36/388): https://pharmastate.academy/courses/total-organic-carbon-analyser/
# 🔄 Scraping (37/388): https://pharmastate.academy/courses/tablet-sizes-in-the-pharmaceutical-industry/
# 🔄 Scraping (38/388): https://pharmastate.academy/courses/new-course-2/
# 🔄 Scraping (39/388): https://pharmastate.academy/courses/sop-for-operation-and-calibration-of-digital-automatic-karl-fischer-titrator/
# 🔄 Scraping (40/388): https://pharmastate.academy/courses/aseptic-processing/
# 🔄 Scraping (41/388): https://pharmastate.academy/courses/face-regulatory-inspection/
# 🔄 Scraping (42/388): https://pharmastate.academy/courses/training-in-pharma/
# 🔄 Scraping (43/388): https://pharmastate.academy/courses/tablet-coatings-in-the-pharmaceutical-industry/
# 🔄 Scraping (44/388): https://pharmastate.academy/courses/fda-inspection-fda-form-483/
# 🔄 Scraping (45/388): https://pharmastate.academy/courses/induction-new-pharma-employees/
# 🔄 Scraping (46/388): https://pharmastate.academy/courses/drug-recalls/
# 🔄 Scraping (47/388): https://pharmastate.academy/courses/standard-operating-procedure-for-sampling/
# 🔄 Scraping (48/388): https://pharmastate.academy/courses/stability-study-protocal-template-pharmaceutical-industry/
# 🔄 Scraping (49/388): https://pharmastate.academy/courses/sop-on-capa/
# 🔄 Scraping (50/388): https://pharmastate.academy/courses/marketing-mix-2/
# 🔄 Scraping (51/388): https://pharmastate.academy/courses/spray-drying-in-pharma-manufacturing/
# 🔄 Scraping (52/388): https://pharmastate.academy/courses/sop-for-user-requirement-specification-in-pharmaceutical-industry/
# 🔄 Scraping (53/388): https://pharmastate.academy/courses/quality-manual/
# 🔄 Scraping (54/388): https://pharmastate.academy/courses/medical-representative-vision/
# 🔄 Scraping (55/388): https://pharmastate.academy/courses/tablet-packaging-in-the-pharmaceutical-industry/
# 🔄 Scraping (56/388): https://pharmastate.academy/courses/quality-agreements-in-pharma-manufacturing/
# 🔄 Scraping (57/388): https://pharmastate.academy/courses/from-alcoa-to-alcoa-plus-data-integrity/
# 🔄 Scraping (58/388): https://pharmastate.academy/courses/usfda-introduction/
# 🔄 Scraping (59/388): https://pharmastate.academy/courses/sop-for-product-recall-in-pharmaceutical-industry/
# 🔄 Scraping (60/388): https://pharmastate.academy/courses/total-quality-management-and-quality-assurance/
# 🔄 Scraping (61/388): https://pharmastate.academy/courses/risk-management-methods-and-tools/
# 🔄 Scraping (62/388): https://pharmastate.academy/courses/medical-representative-challenging-profession-lucrative-career-2/
# 🔄 Scraping (63/388): https://pharmastate.academy/courses/qc-tests-for-ointments-and-creams/
# 🔄 Scraping (64/388): https://pharmastate.academy/courses/pharmacovigilance-role-interview-preparation/
# 🔄 Scraping (65/388): https://pharmastate.academy/courses/quality-risk-management/
# 🔄 Scraping (66/388): https://pharmastate.academy/courses/how-to-say-no/
# 🔄 Scraping (67/388): https://pharmastate.academy/courses/sop-on-sop-how-to-prepare-sop-in-pharmaceutical-industry/
# 🔄 Scraping (68/388): https://pharmastate.academy/courses/qualification-of-tunnel-sterilizing-machine/
# 🔄 Scraping (69/388): https://pharmastate.academy/courses/implementation-of-lean-six-sigma-in-a-pharma-company/
# 🔄 Scraping (70/388): https://pharmastate.academy/courses/central-drugs-standard-control-organization-cdsco/
# 🔄 Scraping (71/388): https://pharmastate.academy/courses/quality-control-tests-for-parenterals-in-the-pharmaceutical-industry/
# 🔄 Scraping (72/388): https://pharmastate.academy/courses/leadership-mini-byte-2-one-minute-manager/
# 🔄 Scraping (73/388): https://pharmastate.academy/courses/closing-of-call-for-medical-representative/
# 🔄 Scraping (74/388): https://pharmastate.academy/courses/interview-questions-regulatory-affairs/
# 🔄 Scraping (75/388): https://pharmastate.academy/courses/validation-calibration-and-qualification/
# 🔄 Scraping (76/388): https://pharmastate.academy/courses/mini-byte-4-situational-leadership/
# 🔄 Scraping (77/388): https://pharmastate.academy/courses/business-model-canvas/
# 🔄 Scraping (78/388): https://pharmastate.academy/courses/marketing-myopia/
# 🔄 Scraping (79/388): https://pharmastate.academy/courses/marketing-myopia-how-missing-the-big-picture-can-stagnate-growth-2/
# 🔄 Scraping (80/388): https://pharmastate.academy/courses/fda-pre-approval-inspection/
# 🔄 Scraping (81/388): https://pharmastate.academy/courses/doctor-call-objection-handling/
# 🔄 Scraping (82/388): https://pharmastate.academy/courses/profound-impact-with-interpersonal-skills/
# 🔄 Scraping (83/388): https://pharmastate.academy/courses/handling-doctors-objection-turn-an-objection-into-an-opportunity-2/
# 🔄 Scraping (84/388): https://pharmastate.academy/courses/handling-doctors-objection/
# 🔄 Scraping (85/388): https://pharmastate.academy/courses/training-on-autoclave/
# 🔄 Scraping (86/388): https://pharmastate.academy/courses/who-guideline-for-sampling-of-pharmaceutical-products/
# 🔄 Scraping (87/388): https://pharmastate.academy/courses/demand-prescription-from-doctor/
# 🔄 Scraping (88/388): https://pharmastate.academy/courses/stages-of-evolution-for-pharma-professionals/
# 🔄 Scraping (89/388): https://pharmastate.academy/courses/five-critical-rules-for-writing-effective-medico-marketing-communication-2/
# 🔄 Scraping (90/388): https://pharmastate.academy/courses/know-your-customers/
# 🔄 Scraping (91/388): https://pharmastate.academy/courses/granulation-techniques-for-tablet-manufacturing/
# 🔄 Scraping (92/388): https://pharmastate.academy/courses/testing-of-pharmaceutical-packaging-materials/
# 🔄 Scraping (93/388): https://pharmastate.academy/courses/understanding-mindset-of-the-doctor/
# 🔄 Scraping (94/388): https://pharmastate.academy/courses/variety-pharma-sales-professionals/
# 🔄 Scraping (95/388): https://pharmastate.academy/courses/quality-control-tests-for-aerosols-in-the-pharmaceutical-industry/
# 🔄 Scraping (96/388): https://pharmastate.academy/courses/microbial-enumeration-tests/
# 🔄 Scraping (97/388): https://pharmastate.academy/courses/change-control-management-in-the-pharmaceutical-landscape/
# 🔄 Scraping (98/388): https://pharmastate.academy/courses/quality-control-tests-for-suppositories-in-the-pharmaceutical-industry/
# 🔄 Scraping (99/388): https://pharmastate.academy/courses/saas-and-cloud-unleashing-pharmas-digital-potential-2/
# 🔄 Scraping (100/388): https://pharmastate.academy/courses/process-capability-utilization-in-the-pharmaceutical-industry/
# 🔄 Scraping (101/388): https://pharmastate.academy/courses/regulatory-affairs-in-pharmaceutical-industry/
# 🔄 Scraping (102/388): https://pharmastate.academy/courses/brand-strategy-with-case-studies/
# 🔄 Scraping (103/388): https://pharmastate.academy/courses/understand-brand-strategy-with-case-studies-2/
# 🔄 Scraping (104/388): https://pharmastate.academy/courses/drug-master-files-in-the-pharmaceutical-industry/
# 🔄 Scraping (105/388): https://pharmastate.academy/courses/basics-of-communication/
# 🔄 Scraping (106/388): https://pharmastate.academy/courses/basics-of-communication-2-2/
# 🔄 Scraping (107/388): https://pharmastate.academy/courses/kaoru-ishikawa-quality-control-tools-in-the-pharmaceutical-landscape/
# 🔄 Scraping (108/388): https://pharmastate.academy/courses/job-responsibilities-zonal-sales-manager-pharma-sales-management/
# 🔄 Scraping (109/388): https://pharmastate.academy/courses/supporting-doctors-in-their-journey-of-publishing/
# 🔄 Scraping (110/388): https://pharmastate.academy/courses/transition-from-first-line-manager-to-vice-president/
# 🔄 Scraping (111/388): https://pharmastate.academy/courses/quality-control-tests-for-ointments-in-pharmaceutical-industry/
# 🔄 Scraping (112/388): https://pharmastate.academy/courses/quality-control-tests-for-capsule-in-the-pharmaceutical-industry/
# 🔄 Scraping (113/388): https://pharmastate.academy/courses/quality-control-tests-for-tablets-in-the-pharmaceutical-industry/
# 🔄 Scraping (114/388): https://pharmastate.academy/courses/medical-sales-representative-interview-preparation/
# 🔄 Scraping (115/388): https://pharmastate.academy/courses/occupational-safety-and-health-administration-osha/
# 🔄 Scraping (116/388): https://pharmastate.academy/courses/checklists-in-pharmaceutical-quality-assurance/
# 🔄 Scraping (117/388): https://pharmastate.academy/courses/stability-studies-in-drug-development-process-1/
# 🔄 Scraping (118/388): https://pharmastate.academy/courses/pharmacovigilance-clinical-trials/
# 🔄 Scraping (119/388): https://pharmastate.academy/courses/good-pharma-manufacturing-practices/
# 🔄 Scraping (120/388): https://pharmastate.academy/courses/guidelines-on-recall-and-rapid-alert-system-for-drugs/
# 🔄 Scraping (121/388): https://pharmastate.academy/courses/sap-systems-applications-products-in-data-processing-in-pharmaceutical-industry/
# 🔄 Scraping (122/388): https://pharmastate.academy/courses/corrective-preventive-actions-in-the-pharmaceutical-industry/
# 🔄 Scraping (123/388): https://pharmastate.academy/courses/attend-your-customer-pharma-managers/
# 🔄 Scraping (124/388): https://pharmastate.academy/courses/transaction-marketing/
# 🔄 Scraping (125/388): https://pharmastate.academy/courses/quality-control-of-packaging-material/
# 🔄 Scraping (126/388): https://pharmastate.academy/courses/analytical-techniques-in-pharmaceutical-landscape/
# 🔄 Scraping (127/388): https://pharmastate.academy/courses/indian-pharmaceutical-industry-history-growth-story/
# 🔄 Scraping (128/388): https://pharmastate.academy/courses/quiz-general-awareness-pharma-manufacturing/
# 🔄 Scraping (129/388): https://pharmastate.academy/courses/deal-with-pressure-in-pharma-sales-and-marketing/
# 🔄 Scraping (130/388): https://pharmastate.academy/courses/know-your-doctors-for-pharma-sales/
# 🔄 Scraping (131/388): https://pharmastate.academy/courses/meaningful-input-utilization-to-generate-prescription/
# 🔄 Scraping (132/388): https://pharmastate.academy/courses/is-digital-overwhelming-digital-in-pharma-made-simple-2/
# 🔄 Scraping (133/388): https://pharmastate.academy/courses/digital-in-pharma-made-simple/
# 🔄 Scraping (134/388): https://pharmastate.academy/courses/quality-risk-management-qrm-in-the-pharmaceutical-landscape/
# 🔄 Scraping (135/388): https://pharmastate.academy/courses/swot-analysis-self-development/
# 🔄 Scraping (136/388): https://pharmastate.academy/courses/swot-ap-analysis-for-self-development-2/
# 🔄 Scraping (137/388): https://pharmastate.academy/courses/statistical-process-control-spc-in-the-pharmaceutical-landscape/
# 🔄 Scraping (138/388): https://pharmastate.academy/courses/days-work-plan-for-medical-representative/
# 🔄 Scraping (139/388): https://pharmastate.academy/courses/days-work-plan-to-generate-prescription/
# 🔄 Scraping (140/388): https://pharmastate.academy/courses/retail-chemist-prescription-audit-2/
# 🔄 Scraping (141/388): https://pharmastate.academy/courses/total-communication/
# 🔄 Scraping (142/388): https://pharmastate.academy/courses/establish-your-executive-presence-with-total-communication-2/
# 🔄 Scraping (143/388): https://pharmastate.academy/courses/defend-your-customer-pharma-managers/
# 🔄 Scraping (144/388): https://pharmastate.academy/courses/pharma-field-sales-manager-and-field-brand-manager/
# 🔄 Scraping (145/388): https://pharmastate.academy/courses/pharma-quality-assurance-interview-preparation/
# 🔄 Scraping (146/388): https://pharmastate.academy/courses/quality-control-tests-for-ophthalmic-products-in-the-pharmaceutical-industry/
# 🔄 Scraping (147/388): https://pharmastate.academy/courses/doctor-call-preparation-for-medical-representative/
# 🔄 Scraping (148/388): https://pharmastate.academy/courses/doctor-call-preparation/
# 🔄 Scraping (149/388): https://pharmastate.academy/courses/pharma-brand-managers-field-work/
# 🔄 Scraping (150/388): https://pharmastate.academy/courses/pharma-brand-managers-and-field-work-2/
# 🔄 Scraping (151/388): https://pharmastate.academy/courses/theory-of-relativity-for-second-line-manager/
# 🔄 Scraping (152/388): https://pharmastate.academy/courses/crafting-a-brand-plan-with-case-studies-2/
# 🔄 Scraping (153/388): https://pharmastate.academy/courses/crafting-a-brand-plan/
# 🔄 Scraping (154/388): https://pharmastate.academy/courses/root-cause-analysis-in-the-pharmaceutical-landscape/
# 🔄 Scraping (155/388): https://pharmastate.academy/courses/second-line-manager-productivity-issues-solutions/
# 🔄 Scraping (156/388): https://pharmastate.academy/courses/retail-chemist-prescription-audit/
# 🔄 Scraping (157/388): https://pharmastate.academy/courses/medical-device-industry-overview-insights-and-opportunties/
# 🔄 Scraping (158/388): https://pharmastate.academy/courses/mystique-of-neural-marketing/
# 🔄 Scraping (159/388): https://pharmastate.academy/courses/explore-the-mystique-of-neural-marketing-2/
# 🔄 Scraping (160/388): https://pharmastate.academy/courses/good-manufacturing-practices-gmp-in-the-pharmaceutical-industry/
# 🔄 Scraping (161/388): https://pharmastate.academy/courses/guidelines-on-good-manufacturing-practices-in-pharma/
# 🔄 Scraping (162/388): https://pharmastate.academy/courses/sop-for-cleaning-procedure-of-general-microbiological-testing-areas/
# 🔄 Scraping (163/388): https://pharmastate.academy/courses/coronavirus-sars-cov-2-covid-19/
# 🔄 Scraping (164/388): https://pharmastate.academy/courses/first-line-manager-productivity-issues-solutions/
# 🔄 Scraping (165/388): https://pharmastate.academy/courses/change-management-systems-in-the-pharmaceutical-industry/
# 🔄 Scraping (166/388): https://pharmastate.academy/courses/clinical-trials-overview/
# 🔄 Scraping (167/388): https://pharmastate.academy/courses/first-line-manager-roles-and-responsibilities-in-pharma-sales/
# 🔄 Scraping (168/388): https://pharmastate.academy/courses/quality-control-quality-assurance-quiz/
# 🔄 Scraping (169/388): https://pharmastate.academy/courses/good-laboratory-practices-in-the-pharmaceutical-landscape/
# 🔄 Scraping (170/388): https://pharmastate.academy/courses/capsule-manufacturing-and-encapsulation-techniques/
# 🔄 Scraping (171/388): https://pharmastate.academy/courses/osteoporosis/
# 🔄 Scraping (172/388): https://pharmastate.academy/courses/skills-to-excel-in-medical-device-industry/
# 🔄 Scraping (173/388): https://pharmastate.academy/courses/drug-discovery-development-in-the-pharmaceutical-industry/
# 🔄 Scraping (174/388): https://pharmastate.academy/courses/packaging-technologies-in-pharmaceutical-industry/
# 🔄 Scraping (175/388): https://pharmastate.academy/courses/literature-search-reference-managements/
# 🔄 Scraping (176/388): https://pharmastate.academy/courses/literature-search-reference-management-in-academic-writing/
# 🔄 Scraping (177/388): https://pharmastate.academy/courses/power-vs-persuasion-pharma-sales/
# 🔄 Scraping (178/388): https://pharmastate.academy/courses/branding-good-name-and-powerful-vision/
# 🔄 Scraping (179/388): https://pharmastate.academy/courses/branding-a-good-name-and-a-powerful-vision-2/
# 🔄 Scraping (180/388): https://pharmastate.academy/courses/medical-representative-mission-statement/
# 🔄 Scraping (181/388): https://pharmastate.academy/courses/biochemical-oxygen-demand-bod/
# 🔄 Scraping (182/388): https://pharmastate.academy/courses/theory-of-independence-for-second-line-manager/
# 🔄 Scraping (183/388): https://pharmastate.academy/courses/job-responsibilities-of-regional-manager-in-pharma-sales/
# 🔄 Scraping (184/388): https://pharmastate.academy/courses/six-sigma-in-the-pharmaceutical-landscape/
# 🔄 Scraping (185/388): https://pharmastate.academy/courses/induction-first-line-manager-in-pharma-sales/
# 🔄 Scraping (186/388): https://pharmastate.academy/courses/influencing-skills-with-subject-knowledge/
# 🔄 Scraping (187/388): https://pharmastate.academy/courses/skillset-required-to-tackle-covid-vuca/
# 🔄 Scraping (188/388): https://pharmastate.academy/courses/pharma-brand-audit-an-essential-component-for-building-mega-brands-2/
# 🔄 Scraping (189/388): https://pharmastate.academy/courses/people-management-in-pharma-sales-and-marketing/
# 🔄 Scraping (190/388): https://pharmastate.academy/courses/pharma-brand-audit/
# 🔄 Scraping (191/388): https://pharmastate.academy/courses/process-analytical-technology/
# 🔄 Scraping (192/388): https://pharmastate.academy/courses/medical-representative-induction/
# 🔄 Scraping (193/388): https://pharmastate.academy/courses/newer-digital-approaches-for-engaging-hcps/
# 🔄 Scraping (194/388): https://pharmastate.academy/courses/pharma-hierarchies/
# 🔄 Scraping (195/388): https://pharmastate.academy/courses/five-types-of-intelligences-pharma-field-force/
# 🔄 Scraping (196/388): https://pharmastate.academy/courses/todays-leadership-principles-and-action-questions/
# 🔄 Scraping (197/388): https://pharmastate.academy/courses/5-types-of-intelligences-for-pharma-field-force-2/
# 🔄 Scraping (198/388): https://pharmastate.academy/courses/third-line-manager-performance/
# 🔄 Scraping (199/388): https://pharmastate.academy/courses/masterclass-on-fundamentals-of-key-account-management/
# 🔄 Scraping (200/388): https://pharmastate.academy/courses/medicomarketing-copywriting-for-pharma-brand-managers-2/
# 🔄 Scraping (201/388): https://pharmastate.academy/courses/common-technical-documents-in-the-pharmaceutical-industry/
# 🔄 Scraping (202/388): https://pharmastate.academy/courses/attrition-reasons-symptoms-solutions/
# 🔄 Scraping (203/388): https://pharmastate.academy/courses/patient-centricity-in-pharma-marketing/
# 🔄 Scraping (204/388): https://pharmastate.academy/courses/voice-of-the-patient-integral-to-patient-centricity-in-pharma-marketing-2/
# 🔄 Scraping (205/388): https://pharmastate.academy/courses/skills-required-to-start-your-career-in-pharma-marketing/
# 🔄 Scraping (206/388): https://pharmastate.academy/courses/using-free-tools-designing-contents-dtips/
# 🔄 Scraping (207/388): https://pharmastate.academy/courses/induction-medical-representative/
# 🔄 Scraping (208/388): https://pharmastate.academy/courses/how-to-stand-out-in-pharma-placement-interviews/
# 🔄 Scraping (209/388): https://pharmastate.academy/courses/tablets-manufacturing-in-pharma/
# 🔄 Scraping (210/388): https://pharmastate.academy/courses/standard-operating-procedure-pharma-manufacturing/
# 🔄 Scraping (211/388): https://pharmastate.academy/courses/phygital-marketing-launch-new-brands/
# 🔄 Scraping (212/388): https://pharmastate.academy/courses/assisting-hcps-publishing-their-case-study-and-create-a-global-impact/
# 🔄 Scraping (213/388): https://pharmastate.academy/courses/medico-marketing-medical-affairs-present-to-future/
# 🔄 Scraping (214/388): https://pharmastate.academy/courses/3-basic-rules-of-content-pharma-brands/
# 🔄 Scraping (215/388): https://pharmastate.academy/courses/leveraging-phygital-marketing-to-launch-new-brands-post-2020-2/
# 🔄 Scraping (216/388): https://pharmastate.academy/courses/leadership-mini-bytes/
# 🔄 Scraping (217/388): https://pharmastate.academy/courses/leadership-mini-bytes-by-vivek-hattangadi-2-2/
# 🔄 Scraping (218/388): https://pharmastate.academy/courses/career-counseling-regulatory-affairs/
# 🔄 Scraping (219/388): https://pharmastate.academy/courses/career-counseling-cloud-computing-in-pharma/
# 🔄 Scraping (220/388): https://pharmastate.academy/courses/microsites-for-pharma-business-growth/
# 🔄 Scraping (221/388): https://pharmastate.academy/courses/understanding-brand-diamond/
# 🔄 Scraping (222/388): https://pharmastate.academy/courses/building-brand-woman-in-pharma-discussion-series/
# 🔄 Scraping (223/388): https://pharmastate.academy/courses/masterclass-on-building-robust-pharma-brands/
# 🔄 Scraping (224/388): https://pharmastate.academy/courses/career-guidance-pharma-manufacturing/
# 🔄 Scraping (225/388): https://pharmastate.academy/courses/hygiene-pharma-professionals/
# 🔄 Scraping (226/388): https://pharmastate.academy/courses/pharma-sales-performace-during-covid/
# 🔄 Scraping (227/388): https://pharmastate.academy/courses/case-study-the-dilemma-of-choosing-the-better-ceo/
# 🔄 Scraping (228/388): https://pharmastate.academy/courses/masterclass-on-the-art-of-brand-differentiation/
# 🔄 Scraping (229/388): https://pharmastate.academy/courses/case-study-can-you-manage-your-boss/
# 🔄 Scraping (230/388): https://pharmastate.academy/courses/the-next-generation-of-kols-how-pharma-marketing-can-adapt-to-the-rise-of-social-media-influencer-doctors/
# 🔄 Scraping (231/388): https://pharmastate.academy/courses/why-pharma-needs-omnichannel-communication-strategy/
# 🔄 Scraping (232/388): https://pharmastate.academy/courses/establish-your-executive-presence-and-accelerate-career-growth/
# 🔄 Scraping (233/388): https://pharmastate.academy/courses/raise-your-pharma-brand-online-with-10-proven-seo-tips/
# 🔄 Scraping (234/388): https://pharmastate.academy/courses/empowering-pharma-marketing-evidence-based-content/
# 🔄 Scraping (235/388): https://pharmastate.academy/courses/strategy-and-strategy-execution/
# 🔄 Scraping (236/388): https://pharmastate.academy/courses/effective-promotional-planning-for-higher-roi/
# 🔄 Scraping (237/388): https://pharmastate.academy/courses/strategy-and-strategy-execution-can-we-make-competition-irrelevant-2/
# 🔄 Scraping (238/388): https://pharmastate.academy/courses/establish-your-executive-presence-and-accelerate-career-growth-2-2/
# 🔄 Scraping (239/388): https://pharmastate.academy/courses/role-of-pr-media-in-pharma/
# 🔄 Scraping (240/388): https://pharmastate.academy/courses/the-3cs-of-digital-marketing/
# 🔄 Scraping (241/388): https://pharmastate.academy/courses/use-of-qr-code-by-pharma/
# 🔄 Scraping (242/388): https://pharmastate.academy/courses/brand-management-module-4/
# 🔄 Scraping (243/388): https://pharmastate.academy/courses/current-good-manufacturing-practices-for-finished-pharmaceuticals-cgmp/
# 🔄 Scraping (244/388): https://pharmastate.academy/courses/drug-regulatory-affairs/
# 🔄 Scraping (245/388): https://pharmastate.academy/courses/masterclass-trends-insights-and-patient-centric-strategies-by-nivedita-parulekar/
# 🔄 Scraping (246/388): https://pharmastate.academy/courses/do-you-deserve-a-job/
# 🔄 Scraping (247/388): https://pharmastate.academy/courses/masterclass-international-pharma-marketing-career-development/
# 🔄 Scraping (248/388): https://pharmastate.academy/courses/panel-discussion-on-generic-v-s-branded-drugs-what-is-right-for-india/
# 🔄 Scraping (249/388): https://pharmastate.academy/courses/fundamentals-of-communications-for-pharma-brand-management/
# 🔄 Scraping (250/388): https://pharmastate.academy/courses/revised-schedule-m-hvac-systems-qualification/
# 🔄 Scraping (251/388): https://pharmastate.academy/courses/masterclass-overcoming-the-challenges-faced-by-first-time-managers/
# 🔄 Scraping (252/388): https://pharmastate.academy/courses/social-media-management-for-pharma-companies/
# 🔄 Scraping (253/388): https://pharmastate.academy/courses/stressbuster-stress-management-techniques-for-pharma-professionals/
# 🔄 Scraping (254/388): https://pharmastate.academy/courses/revised-schedule-m-materials-vendor-qualification-and-reference-standards/
# 🔄 Scraping (255/388): https://pharmastate.academy/courses/revised-schedule-m-manufacture-of-active-pharmaceuticals-ingredients/
# 🔄 Scraping (256/388): https://pharmastate.academy/courses/revised-schedule-m-good-documentation-practices/
# 🔄 Scraping (257/388): https://pharmastate.academy/courses/masterclass-doctors-and-patients-insights/
# 🔄 Scraping (258/388): https://pharmastate.academy/courses/h2h-marketing-explained/
# 🔄 Scraping (259/388): https://pharmastate.academy/courses/masterclass-brand-review/
# 🔄 Scraping (260/388): https://pharmastate.academy/courses/how-cmes-influence-the-prescription-behaviour-of-doctors/
# 🔄 Scraping (261/388): https://pharmastate.academy/courses/netiquettes-art-of-writing-effective-messages/
# 🔄 Scraping (262/388): https://pharmastate.academy/courses/netiquettes-the-art-of-writing-effective-e-mails-text-messages-and-posts-2/
# 🔄 Scraping (263/388): https://pharmastate.academy/courses/the-current-shift-how-successful-pharma-brands-are-rethinking-hcps-advisory-board-adboards/
# 🔄 Scraping (264/388): https://pharmastate.academy/courses/know-yourself-profession-customers/
# 🔄 Scraping (265/388): https://pharmastate.academy/courses/spoken-english-for-employability/
# 🔄 Scraping (266/388): https://pharmastate.academy/courses/change-management-in-pharma-selling/
# 🔄 Scraping (267/388): https://pharmastate.academy/courses/digital-and-conventional-marketing-in-pharma/
# 🔄 Scraping (268/388): https://pharmastate.academy/courses/promotion-pharma-sales/
# 🔄 Scraping (269/388): https://pharmastate.academy/courses/masterclass-effective-investigations-for-ensuring-quality-and-compliance/
# 🔄 Scraping (270/388): https://pharmastate.academy/courses/manufacture-of-oral-solid-dosage-forms-osd/
# 🔄 Scraping (271/388): https://pharmastate.academy/courses/revised-schedule-m-self-inspection-quality-audits/
# 🔄 Scraping (272/388): https://pharmastate.academy/courses/revised-schedule-m-complaints-product-recall/
# 🔄 Scraping (273/388): https://pharmastate.academy/courses/revised-schedule-m-quality-risk-management-qrm/
# 🔄 Scraping (274/388): https://pharmastate.academy/courses/mooc-online-course-proposal-development/
# 🔄 Scraping (275/388): https://pharmastate.academy/courses/genuine-book-writing-2/
# 🔄 Scraping (276/388): https://pharmastate.academy/courses/mooc-massive-open-online-course-proposal-development/
# 🔄 Scraping (277/388): https://pharmastate.academy/courses/thesis-writing-2/
# 🔄 Scraping (278/388): https://pharmastate.academy/courses/genuine-book-writing/
# 🔄 Scraping (279/388): https://pharmastate.academy/courses/masterclass-essential-quality-assurance-practices-in-pharma/
# 🔄 Scraping (280/388): https://pharmastate.academy/courses/revised-schedule-m-pharmaceutical-quality-system/
# 🔄 Scraping (281/388): https://pharmastate.academy/courses/revised-schedule-m-overview-implementation-plan/
# 🔄 Scraping (282/388): https://pharmastate.academy/courses/leveraging-real-world-evidence-for-building-pharma-brands/
# 🔄 Scraping (283/388): https://pharmastate.academy/courses/the-future-of-smart-labs-pharma-world-quizcon/
# 🔄 Scraping (284/388): https://pharmastate.academy/courses/basic-good-manufacturing-practices/
# 🔄 Scraping (285/388): https://pharmastate.academy/courses/research-grant-proposal-writing-2-2/
# 🔄 Scraping (286/388): https://pharmastate.academy/courses/qualitative-research-and-review-writing/
# 🔄 Scraping (287/388): https://pharmastate.academy/courses/research-article-writing/
# 🔄 Scraping (288/388): https://pharmastate.academy/courses/qualitative-research-and-review-writing-by-dr-ajay-semalty/
# 🔄 Scraping (289/388): https://pharmastate.academy/courses/microsoft-office-tools-for-making-academic-writing-easy-and-effective/
# 🔄 Scraping (290/388): https://pharmastate.academy/courses/microsoft-office-tools-for-academic-writing/
# 🔄 Scraping (291/388): https://pharmastate.academy/courses/detection-avoiding-plagiarism-research-publication/
# 🔄 Scraping (292/388): https://pharmastate.academy/courses/h2h-marketing-event-philip-kotler/
# 🔄 Scraping (293/388): https://pharmastate.academy/courses/medical-research-article-writing/
# 🔄 Scraping (294/388): https://pharmastate.academy/courses/8-habits-successful-brand-manager/
# 🔄 Scraping (295/388): https://pharmastate.academy/courses/systematic-review-and-meta-analysis-dr-ajay-semalty/
# 🔄 Scraping (296/388): https://pharmastate.academy/courses/systematic-review-meta-analysis/
# 🔄 Scraping (297/388): https://pharmastate.academy/courses/8-habits-of-a-successful-brand-manager-2/
# 🔄 Scraping (298/388): https://pharmastate.academy/courses/advanced-ceritificate-course-plagiarism-on-demand/
# 🔄 Scraping (299/388): https://pharmastate.academy/courses/detection-and-avoiding-plagiarism-in-research-and-publications-advanced/
# 🔄 Scraping (300/388): https://pharmastate.academy/courses/masterclass-in-ai-based-pharma-marketing/
# 🔄 Scraping (301/388): https://pharmastate.academy/courses/medical-representative-training-certificate-course/
# 🔄 Scraping (302/388): https://pharmastate.academy/courses/pre-world-pharma-brand-managers-day/
# 🔄 Scraping (303/388): https://pharmastate.academy/courses/lead-your-brand-and-company-to-better-profits-with-h2h-marketing/
# 🔄 Scraping (304/388): https://pharmastate.academy/courses/world-pharma-brand-managers-day-2022-day-2/
# 🔄 Scraping (305/388): https://pharmastate.academy/courses/brand-management-module-5/
# 🔄 Scraping (306/388): https://pharmastate.academy/courses/now-next-summit-on-pharma-marketing-edition-2/
# 🔄 Scraping (307/388): https://pharmastate.academy/courses/c-suite-readiness-program/
# 🔄 Scraping (308/388): https://pharmastate.academy/courses/brand-management-module-1/
# 🔄 Scraping (309/388): https://pharmastate.academy/courses/brand-management-module-2/
# 🔄 Scraping (310/388): https://pharmastate.academy/courses/brand-management-module-3/
# 🔄 Scraping (311/388): https://pharmastate.academy/courses/world-pharma-brand-manager-day-2022-day-1/
# 🔄 Scraping (312/388): https://pharmastate.academy/courses/pbm-saseas-21/
# 🔄 Scraping (313/388): https://pharmastate.academy/courses/world-pharma-brand-managers-day-2021/
# 🔄 Scraping (314/388): https://pharmastate.academy/courses/thesis-writing-advanced/
# 🔄 Scraping (315/388): https://pharmastate.academy/courses/systematic-review-meta-analysis-advanced/
# 🔄 Scraping (316/388): https://pharmastate.academy/courses/excellence-in-pharma-brand-management/
# 🔄 Scraping (317/388): https://pharmastate.academy/courses/systematic-review-meta-analysis-advanced-2/
# 🔄 Scraping (318/388): https://pharmastate.academy/courses/effective-academic-writing-the-art-and-science/
# 🔄 Scraping (319/388): https://pharmastate.academy/courses/world-pharma-brand-manager-day-2023/
# 🔄 Scraping (320/388): https://pharmastate.academy/courses/world-pharma-brand-managers-week-2024-online/
# 🔄 Scraping (321/388): https://pharmastate.academy/courses/medical-representative-assessment/
# 🔄 Scraping (322/388): https://pharmastate.academy/courses/silence-is-virtue-pills-of-motivation/
# 🔄 Scraping (323/388): https://pharmastate.academy/courses/social-media-kick-starter-pack/
# 🔄 Scraping (324/388): https://pharmastate.academy/courses/online-teaching-and-learning/
# 🔄 Scraping (325/388): https://pharmastate.academy/courses/preparing-for-audits/
# 🔄 Scraping (326/388): https://pharmastate.academy/courses/change-control-in-pharma/
# 🔄 Scraping (327/388): https://pharmastate.academy/courses/masterclass-on-asking-the-right-questions-during-review-meetings/
# 🔄 Scraping (328/388): https://pharmastate.academy/courses/placement-season-masterclass/
# 🔄 Scraping (329/388): https://pharmastate.academy/courses/online-teaching-and-learning-2/
# 🔄 Scraping (330/388): https://pharmastate.academy/courses/usfda-inspection-form-482-483-484/
# 🔄 Scraping (331/388): https://pharmastate.academy/courses/sop-for-incident-handling-in-pharmaceutical-industry/
# 🔄 Scraping (332/388): https://pharmastate.academy/courses/sop-on-data-integrity-in-pharmaceutical-industry/
# 🔄 Scraping (333/388): https://pharmastate.academy/courses/sop-for-failure-investigation-in-pharmaceutical-industry/
# 🔄 Scraping (334/388): https://pharmastate.academy/courses/4ps-of-digital-health/
# 🔄 Scraping (335/388): https://pharmastate.academy/courses/research-article-writing-2/
# 🔄 Scraping (336/388): https://pharmastate.academy/courses/detection-and-avoiding-plagiarism-in-research-and-publications/
# 🔄 Scraping (337/388): https://pharmastate.academy/courses/qc-tests-for-packaging-materials/
# 🔄 Scraping (338/388): https://pharmastate.academy/courses/leadership-mini-byte-1-leadership-grid/
# 🔄 Scraping (339/388): https://pharmastate.academy/courses/sop-for-line-clearance/
# 🔄 Scraping (340/388): https://pharmastate.academy/courses/procedure-of-planned-modification/
# 🔄 Scraping (341/388): https://pharmastate.academy/courses/sop-on-market-complaints-related-to-intermediates-api/
# 🔄 Scraping (342/388): https://pharmastate.academy/courses/leadership-mini-byte-3-servant-leadership/
# 🔄 Scraping (343/388): https://pharmastate.academy/courses/international-organization-for-standardization-iso-9001-14001/
# 🔄 Scraping (344/388): https://pharmastate.academy/courses/quality-unit-in-pharma-industry/
# 🔄 Scraping (345/388): https://pharmastate.academy/courses/5-whys-technique-an-investigation-tool-in-pharma/
# 🔄 Scraping (346/388): https://pharmastate.academy/courses/quality-assurance-interview-preparation/
# 🔄 Scraping (347/388): https://pharmastate.academy/courses/lean-six-sigma-methodology-basics/
# 🔄 Scraping (348/388): https://pharmastate.academy/courses/mini-byte-6-why-some-incompetent-people-are-our-leaders/
# 🔄 Scraping (349/388): https://pharmastate.academy/courses/act-of-kindness-pills-of-motivation/
# 🔄 Scraping (350/388): https://pharmastate.academy/courses/medico-marketing-copywriting-for-pharma-brand-managers/
# 🔄 Scraping (351/388): https://pharmastate.academy/courses/linkedin-profile-optimization/
# 🔄 Scraping (352/388): https://pharmastate.academy/courses/different-perspectives-pharma-sales-professionals/
# 🔄 Scraping (353/388): https://pharmastate.academy/courses/situational-understanding-pills-of-motivation/
# 🔄 Scraping (354/388): https://pharmastate.academy/courses/hope-and-faith-pharma-sales-professionals/
# 🔄 Scraping (355/388): https://pharmastate.academy/courses/open-doctors-call/
# 🔄 Scraping (356/388): https://pharmastate.academy/courses/medical-representative-challenging-profession-lucrative-career/
# 🔄 Scraping (357/388): https://pharmastate.academy/courses/effective-closing-of-call/
# 🔄 Scraping (358/388): https://pharmastate.academy/courses/five-critical-rules-medico-marketing-copy/
# 🔄 Scraping (359/388): https://pharmastate.academy/courses/meaningful-input-utilization-for-medical-representative/
# 🔄 Scraping (360/388): https://pharmastate.academy/courses/job-responsibilities-first-line-manager-pharma-sales/
# 🔄 Scraping (361/388): https://pharmastate.academy/courses/promotion-in-pharma-sales/
# 🔄 Scraping (362/388): https://pharmastate.academy/courses/field-work-norms-post-covid-lockdown/
# 🔄 Scraping (363/388): https://pharmastate.academy/courses/quality-control-in-the-pharmaceutical-industry/
# 🔄 Scraping (364/388): https://pharmastate.academy/courses/marketing-mix/
# 🔄 Scraping (365/388): https://pharmastate.academy/courses/know-your-customers-pharma-managers/
# 🔄 Scraping (366/388): https://pharmastate.academy/courses/human-resource-angle-in-sales-and-marketing-2/
# 🔄 Scraping (367/388): https://pharmastate.academy/courses/pharma-professionals-medical-representative/
# 🔄 Scraping (368/388): https://pharmastate.academy/courses/job-responsibilities-medical-representative/
# 🔄 Scraping (369/388): https://pharmastate.academy/courses/gemba-walk-in-pharma-industry/
# 🔄 Scraping (370/388): https://pharmastate.academy/courses/aseptic-area-training-in-pharma-industry/
# 🔄 Scraping (371/388): https://pharmastate.academy/courses/gmp-document-simplification/
# 🔄 Scraping (372/388): https://pharmastate.academy/courses/sop-for-cleaning-of-conveyor-belt/
# 🔄 Scraping (373/388): https://pharmastate.academy/courses/certificate-of-analysis/
# 🔄 Scraping (374/388): https://pharmastate.academy/courses/career-pharma-quality-assurance/
# 🔄 Scraping (375/388): https://pharmastate.academy/courses/drug-relglatory-affairs-its-common-terminologies/
# 🔄 Scraping (376/388): https://pharmastate.academy/courses/orange-book-used-in-the-pharmaceutical-landscape/
# 🔄 Scraping (377/388): https://pharmastate.academy/courses/definitions-as-per-cgmp/
# 🔄 Scraping (378/388): https://pharmastate.academy/courses/career-pharma-quality-control/
# 🔄 Scraping (379/388): https://pharmastate.academy/courses/types-of-tablets-in-the-pharmaceutical-industry/
# 🔄 Scraping (380/388): https://pharmastate.academy/courses/guidance-for-industry-microbiology-laboratories/
# 🔄 Scraping (381/388): https://pharmastate.academy/courses/tablet-manufacturing-defects-in-the-pharmaceutical-industry/
# 🔄 Scraping (382/388): https://pharmastate.academy/courses/national-accreditation-board-for-testing-calibration-laboratories-nabl/
# 🔄 Scraping (383/388): https://pharmastate.academy/courses/sop-on-deviation/
# 🔄 Scraping (384/388): https://pharmastate.academy/courses/why-fda-regulatory-inspection-comes/
# 🔄 Scraping (385/388): https://pharmastate.academy/courses/sampling-tools/
# 🔄 Scraping (386/388): https://pharmastate.academy/courses/pharma-regulations-and-guidelines-india-easy-access-links/
# 🔄 Scraping (387/388): https://pharmastate.academy/courses/personal-protective-equipment-ppes-safety-guideline/
# 🔄 Scraping (388/388): https://pharmastate.academy/courses/pharma-enegma-exploring-next-gen-marketing-advancements/
#
# ✅ All courses saved to Excel: C:\Users\taslim.siddiqui\Downloads\pharmastate_course_combined_FINAL_10_09_2025.xlsx
