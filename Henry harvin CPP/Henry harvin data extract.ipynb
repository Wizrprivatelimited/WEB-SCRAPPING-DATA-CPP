# %% [markdown]
# INPUT FILE IS IN EXCEL WITHOUT  FAQ

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import pandas as pd
from bs4 import BeautifulSoup
import time
import os


# ================= Driver Setup =================
def get_driver():
    options = uc.ChromeOptions()
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--window-size=1280,720")
    options.add_argument("--log-level=3")
    return uc.Chrome(options=options, version_main=138)


def clean_text(text):
    """Clean and normalize text"""
    if text:
        text = ' '.join(text.split())  # Remove extra whitespace
        text = text.replace('\xa0', ' ')  # Replace non-breaking spaces
        text = text.replace('"', "'")  # Normalize quotes
    return text.strip() if text else ""


# ================= Certificate Extraction =================
def extract_certificate_image(soup):
    """Extract certificate image URL from the page"""
    certificate_div = soup.find(
        "div", id=lambda x: x and ("cerificate" in x.lower() or "certificate" in x.lower())
    )
    if certificate_div:
        img_tag = certificate_div.find("img")
        if img_tag and "src" in img_tag.attrs:
            return img_tag["src"]
    return "Certificate image not found"


# ================= Syllabus Extraction =================
def extract_syllabus(soup):
    syllabus = []
    curriculum_div = soup.find("div", id="curriculum")

    if curriculum_div:
        modules = curriculum_div.find_all("li", class_="bg-white my-2 shadow-lg")

        for module in modules:
            # Extract module title
            title_span = module.find("span")
            if title_span:
                module_title = clean_text(title_span.get_text())
                syllabus.append(f"\n🔹 {module_title}\n")

            # Extract module content
            content_div = module.find("div", class_="mx-6 pl-6")
            if content_div:
                for elem in content_div.children:
                    if elem.name == "p":  # Paragraphs
                        strong = elem.find("strong")
                        if strong:
                            strong_text = clean_text(strong.get_text())
                            syllabus.append(f"\n📌 {strong_text}\n")
                            remaining_text = clean_text(elem.text.replace(strong.text, ""))
                            if remaining_text:
                                syllabus.append(f"   {remaining_text}\n")
                        else:
                            text = clean_text(elem.get_text())
                            if text:
                                syllabus.append(f"   {text}\n")

                    elif elem.name == "ul":  # Bullet lists
                        for li in elem.find_all("li"):
                            li_text = clean_text(li.get_text())
                            if li_text:
                                syllabus.append(f"   - {li_text}\n")

                    elif elem.string and elem.string.strip():  # Plain text nodes
                        text = clean_text(elem.string)
                        if text:
                            syllabus.append(f"   {text}\n")

            syllabus.append("\n")  # Add extra line between modules

    return ''.join(syllabus).strip() if syllabus else "Syllabus not available"


# ================= Course Data Extraction =================
def extract_course_data(url):
    driver = None
    try:
        driver = get_driver()
        driver.get(url)

        # Wait for page to load
        time.sleep(5)

        # Scroll to trigger content loading
        for _ in range(3):
            driver.execute_script("window.scrollBy(0, 500)")
            time.sleep(1)

        # Get page source for BeautifulSoup
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')

        # Extract course name
        course_name = "Not Found"
        try:
            course_name = clean_text(soup.find("h1").get_text())
        except:
            pass

        # Extract about course (all paragraphs)
        about_course = "Not Found"
        try:
            about_div = soup.find("div", class_="font-ad")
            if about_div:
                paragraphs = [clean_text(p.get_text()) for p in about_div.find_all("p")]
                about_course = " ".join(p for p in paragraphs if p)
        except:
            pass

        # Extract syllabus
        syllabus = extract_syllabus(soup)

        # Extract certificate image
        certificate_image = extract_certificate_image(soup)

        return {
            'Course Name': course_name,
            'About Course': about_course,
            'Syllabus': syllabus,
            'Certificate Image URL': certificate_image,
            'URL': url
        }

    except Exception as e:
        print(f"Error occurred while scraping {url}: {str(e)}")
        return {
            'Course Name': 'Error',
            'About Course': 'Error',
            'Syllabus': 'Error',
            'Certificate Image URL': 'Error',
            'URL': url
        }
    finally:
        if driver:
            driver.quit()


# ================= Save to Excel =================
def save_to_excel(data, filename="course_data.xlsx"):
    df = pd.DataFrame([data])
    try:
        existing_df = pd.read_excel(filename)
        if data['URL'] not in existing_df['URL'].values:
            updated_df = pd.concat([existing_df, df], ignore_index=True)
            updated_df.to_excel(filename, index=False)
            print(f"Data appended to {filename}")
        else:
            print(f"Data for {data['URL']} already exists in {filename}")
    except FileNotFoundError:
        df.to_excel(filename, index=False)
        print(f"New file {filename} created")


# ================= Read URLs from Excel =================
def read_urls_from_excel(file_path, url_column="URL"):
    try:
        df = pd.read_excel(file_path)
        if url_column in df.columns:
            return df[url_column].dropna().unique().tolist()
        else:
            print(f"Error: Column '{url_column}' not found in the Excel file")
            return []
    except Exception as e:
        print(f"Error reading Excel file: {str(e)}")
        return []


# ================= Main =================
def main():
    input_file = r"C:\Users\taslim.siddiqui\Downloads\Pending.xlsx"
    output_file = r"C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx"

    urls = read_urls_from_excel(input_file)

    if not urls:
        print("No URLs found in the input file. Please check your Excel file.")
        return

    print(f"Found {len(urls)} URLs to scrape")

    for url in urls:
        print(f"\nScraping: {url}")
        course_data = extract_course_data(url)
        print(f"Course Name: {course_data['Course Name']}")
        save_to_excel(course_data, filename=output_file)
        print("---")

    print("\nScraping completed!")


if __name__ == "__main__":
    main()
# Out:
# Found 6 URLs to scrape
#
# Scraping: https://www.henryharvin.com/medical-billing-course
# Course Name: Medical Billing Course Training
# New file C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx created
# ---
#
# Scraping: https://www.henryharvin.com/french-language-course
# Course Name: French Language Course
# Data appended to C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx
# ---
#
# Scraping: https://www.henryharvin.com/blockchain-certification-training
# Course Name: Blockchain Certification Training Course
# Data appended to C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx
# ---
#
# Scraping: https://www.henryharvin.com/patent-drafting-course
# Course Name: Patent Drafting Course
# Data appended to C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx
# ---
#
# Scraping: Certificate Course on Property Law (henryharvin.com)
# Error occurred while scraping Certificate Course on Property Law (henryharvin.com): Message: invalid argument
#   (Session info: chrome=139.0.7258.67)
# Stacktrace:
# 	GetHandleVerifier [0x0xddba83+63395]
# 	GetHandleVerifier [0x0xddbac4+63460]
# 	(No symbol) [0x0xc21f70]
# 	(No symbol) [0x0xc126e5]
# 	(No symbol) [0x0xc10d99]
# 	(No symbol) [0x0xc114eb]
# 	(No symbol) [0x0xc25b3e]
# 	(No symbol) [0x0xcb1387]
# 	(No symbol) [0x0xc8f3ac]
# 	(No symbol) [0x0xcb07ba]
# 	(No symbol) [0x0xc8f1a6]
# 	(No symbol) [0x0xc5e7b2]
# 	(No symbol) [0x0xc5f654]
# 	GetHandleVerifier [0x0x1058883+2672035]
# 	GetHandleVerifier [0x0x1053cba+2652634]
# 	GetHandleVerifier [0x0xe02bca+223466]
# 	GetHandleVerifier [0x0xdf2cb8+158168]
# 	GetHandleVerifier [0x0xdf978d+185517]
# 	GetHandleVerifier [0x0xde3b78+96408]
# 	GetHandleVerifier [0x0xde3d02+96802]
# 	GetHandleVerifier [0x0xdce90a+9770]
# 	BaseThreadInitThunk [0x0x75ee5d49+25]
# 	RtlInitializeExceptionChain [0x0x7743d1ab+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x7743d131+561]
#
# Course Name: Error
# Data appended to C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx
# ---
#
# Scraping: https://www.henryharvin.com/pmi-dassm-certification-training-course
# Course Name: Not Found
# Data appended to C:\Users\taslim.siddiqui\Downloads\HENRY pending data 6.xlsx
# ---
#
# Scraping completed!

# %% [markdown]
# INPUT FILE IS EXCEL FILE  with FAQ

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import pandas as pd
from bs4 import BeautifulSoup
import time
import os

# ================= Driver Setup =================
def get_driver():
    options = uc.ChromeOptions()
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--window-size=1280,720")
    options.add_argument("--log-level=3")
    return uc.Chrome(options=options, version_main=138)

def clean_text(text):
    """Clean and normalize text"""
    if text:
        text = ' '.join(text.split())  # Remove extra whitespace
        text = text.replace('\xa0', ' ')  # Replace non-breaking spaces
        text = text.replace('"', "'")  # Normalize quotes
    return text.strip() if text else ""

# ================= Certificate Extraction =================
def extract_certificate_image(soup):
    """Extract certificate image URL from the page"""
    certificate_div = soup.find("div", id=lambda x: x and "cerificate" in x.lower())
    if certificate_div:
        img_tag = certificate_div.find("img")
        if img_tag and "src" in img_tag.attrs:
            return img_tag["src"]
    return "Certificate image not found"

# ================= Syllabus Extraction =================
def extract_syllabus(soup):
    syllabus = []
    curriculum_div = soup.find("div", id="curriculum")
    
    if curriculum_div:
        modules = curriculum_div.find_all("li", class_="bg-white my-2 shadow-lg")
        
        for module in modules:
            # Extract module title
            title_span = module.find("span")
            if title_span:
                module_title = clean_text(title_span.get_text())
                syllabus.append(f"\n🔹 {module_title}\n")
            
            # Extract module content
            content_div = module.find("div", class_="mx-6 pl-6")
            if content_div:
                for elem in content_div.children:
                    if elem.name == "p":  # Paragraphs
                        strong = elem.find("strong")
                        if strong:
                            strong_text = clean_text(strong.get_text())
                            syllabus.append(f"\n📌 {strong_text}\n")
                            remaining_text = clean_text(elem.text.replace(strong.text, ""))
                            if remaining_text:
                                syllabus.append(f"   {remaining_text}\n")
                        else:
                            text = clean_text(elem.get_text())
                            if text:
                                syllabus.append(f"   {text}\n")
                    
                    elif elem.name == "ul":  # Bullet lists
                        for li in elem.find_all("li"):
                            li_text = clean_text(li.get_text())
                            if li_text:
                                syllabus.append(f"   - {li_text}\n")
                    
                    elif elem.string and elem.string.strip():  # Plain text nodes
                        text = clean_text(elem.string)
                        if text:
                            syllabus.append(f"   {text}\n")
            
            syllabus.append("\n")  # Add extra line between modules
    
    return ''.join(syllabus).strip() if syllabus else "Syllabus not available"

# ================= FAQ Extraction =================
def extract_faq_text(soup):
    faq_items = soup.find_all("li", class_="bg-white my-2")
    faq_text_list = []
    for li in faq_items:
        question_tag = li.find("h2")
        question = question_tag.get_text(strip=True) if question_tag else ""
        answer_div = li.find("div", {"x-ref": "tab"})
        if answer_div:
            answer_parts = []
            for p in answer_div.find_all("p"):
                text = p.get_text(strip=True)
                if text and not text.lower().startswith("looking for as an it security analyst"):
                    answer_parts.append(text)
            answer = " ".join(answer_parts)
        else:
            answer = ""
        if question or answer:
            faq_text_list.append(f"Q: {question}\nA: {answer}")
    return "\n\n".join(faq_text_list) if faq_text_list else "FAQ not available"

# ================= Course Data Extraction =================
def extract_course_data(url):
    driver = None
    try:
        driver = get_driver()
        driver.get(url)
        
        time.sleep(5)
        
        for _ in range(3):
            driver.execute_script("window.scrollBy(0, 500)")
            time.sleep(1)
        
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        # Course name
        try:
            course_name = clean_text(soup.find("h1").get_text())
        except:
            course_name = "Not Found"
        
        # About course
        try:
            about_course = "Not Found"
            about_div = soup.find("div", class_="font-ad")
            if about_div:
                about_paragraph = about_div.find("p")
                if about_paragraph:
                    about_course = clean_text(about_paragraph.get_text())
        except:
            about_course = "Not Found"
        
        # Syllabus
        syllabus = extract_syllabus(soup)
        
        # Certificate image
        certificate_image = extract_certificate_image(soup)
        
        # FAQ
        faq_text = extract_faq_text(soup)
        
        return {
            'Course Name': course_name,
            'About Course': about_course,
            'Syllabus': syllabus,
            'Certificate Image URL': certificate_image,
            'FAQ': faq_text,
            'URL': url
        }
        
    except Exception as e:
        print(f"Error occurred while scraping {url}: {str(e)}")
        return {
            'Course Name': 'Error',
            'About Course': 'Error',
            'Syllabus': 'Error',
            'Certificate Image URL': 'Error',
            'FAQ': 'Error',
            'URL': url
        }
    finally:
        if driver:
            driver.quit()

# ================= Process Input File =================
def process_input_file(input_file, output_file):
    df_input = pd.read_excel(input_file)
    all_data = []
    for _, row in df_input.iterrows():
        url = row['URL']
        course_data = extract_course_data(url)
        
        # ✅ Print course name & link
        print(f"Course Name: {course_data['Course Name']}")
        print(f"Course Link: {course_data['URL']}\n")
        print(f"Course Name: {course_data['Course Name']}")
        print(f"Syllabus:\n{course_data['Syllabus']}")
        
        all_data.append(course_data)
    
    df_output = pd.DataFrame(all_data)
    df_output.to_excel(output_file, index=False)
    print(f"Data saved to {output_file}")

# ================= Run Script =================
if __name__ == "__main__":
    input_file = r"C:\Users\taslim.siddiqui\Downloads\HenryHarvin_All_Courses (2).xlsx"
    output_file = r"C:\Users\taslim.siddiqui\Downloads\HENRY_Raghu.xlsx"
    process_input_file(input_file, output_file)
# Out:
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Course Link: https://www.henryharvin.com/3d-vfx-course
#
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Syllabus:
# Syllabus not available
# Course Name: ASTB Test Prep Course
# Course Link: https://www.henryharvin.com/astb-test-prep-course
#
# Course Name: ASTB Test Prep Course
# Syllabus:
# 🔹 Module 1: MST (Math Skills Test)
#    This includes elementary probability questions as well as some simple word problems involving time and distance. Also contain some basic geometry, algebra, angles, and perimeter.
#
#
# 🔹 Module 2: RCT (Reading Comprehension Test)
#    This section tests the ability to read and comprehend passages. Identifying the passage's main idea or determining whether it supports a particular claim will frequently be asked of learners.
#
#
# 🔹 Module 3: MCT (Mechanical Comprehension Test)
#    Understanding of fundamental physics and mechanics principles will be evaluated by this subtest. Gasses and liquids, pressure, volume, velocity, engine parts and performance, electrical principles, gears, weight distribution, and the operation of simple machines were some of the subjects covered.
#
#
# 🔹 Module 4: ANIT (Aviation and Nautical Information Test)
#    This section will make learners familiar with some nautical jargon, some aviation history, as well as some basic aviation concepts like aerodynamics, fundamental aircraft parts, and flight regulations in order to pass this section of the ASTB.
#
#
# 🔹 Module 5: NATFI (Naval Aviation Trait Facet Inventory)
#    It is a personality inventory that will ultimately determine a person's suitability for an aviation career based on their individual traits.
#
#
# 🔹 Module 6: PBM (Performance Based Measures)
#    Situational awareness, dexterity, aptitude for spatial orientation, and multitasking are all measured by this subtest. After receiving a problem requiring the identification of cardinal directions, the user will track an airplane on a screen using a joystick and throttle (flight simulation). Prepare for this section by working out problems involving mental rotation.
#
#
# 🔹 Module 7: BI-RV (Biographical Inventory With Response Validation)
#    This subtest's objective is to assess the capacity for completing naval training by learning more about the background and experiences of the participants. There are 110 questions on it, and it must be finished at home.
# Course Name: ASVAB Preparation Course
# Course Link: https://www.henryharvin.com/asvab-prep-course
#
# Course Name: ASVAB Preparation Course
# Syllabus:
# 🔹 Module 1: General Science
#    - Life science: botany, zoology, anatomy and physiology, ecology
#    - Physical science: force and motion, energy, fluids and gases, atomic structure, chemistry
#    - Earth and space science: astronomy, geology, meteorology, oceanography
#
#
# 🔹 Module 2: Arithmetic Reasoning
#    - Operations with whole numbers
#    - Operations with fractions and decimals or money
#    - Ratio and proportion
#    - Interest and percentage
#    - Measurement of perimeters, areas, volumes, and time and temperature
#
#
# 🔹 Module 3: Word Knowledge
#    - Definitions presented alone, with no context
#    - Words in the context of a short sentence
#
#
# 🔹 Module 4: Paragraph Comprehension
#    - Literal comprehension: your ability to identify stated facts, identify reworded facts, and determine sequence of events
#    - Implicit, inferential, or critical comprehension: your ability to draw conclusions; identify the main idea of a paragraph; determine the author’s purpose, mood, or tone; and identify style and technique
#
#
# 🔹 Module 5: Auto and Shop Information
#    - Automotive components
#    - Automotive systems
#    - Automotive tools
#    - Automotive troubleshooting and repair
#    - Shop tools
#    - Building materials
#    - Building and construction procedures
#
#
# 🔹 Module 6: Mathematics Knowledge
#    - Number theory: factors, multiples, reciprocals, number properties, primes, integers
#    - Numeration: fractional parts, decimals, percentages, and conversions; order of operations; exponents; rounding; reducing fractions; roots and radicals; signed numbers
#    - Algebraic operations and equations: solving or determining equations, factoring, simplifying Algebraic expressions, converting a sentence to an equation
#    - Geometry and measurement: coordinates and slope, Pythagorean theorem, angle measurement, properties of polygons and circles, perimeter, area, volume, unit conversion
#    - Probability
#
#
# 🔹 Module 7: Mechanical Comprehension
#    - Basic compound machines: gears, cams, pistons, cranks, linkages, belts, chains
#    - Simple machines: levers, planes, pulleys, screws, wedges, wheels, axles
#    - Mechanical motion: friction, velocity, direction, acceleration, centrifugal force
#    - Fluid dynamics: hydraulic forces, compression
#    - Properties of materials: weight, strength, expansion/contraction, absorption, center of gravity
#    - Structural support
#
#
# 🔹 Module 8: Electronics Information
#    - Electrical tools, symbols, devices, and materials
#    - Electrical circuits
#    - Electricity and electronic systems
#    - Electrical current: voltage, conductivity, resistance, grounding
#
#
# 🔹 Module 9: Assembling Objects
#    - Problem-solving strategies for puzzles
#    - Application of methods for solving various puzzle types
#    - Strategies for connection problems
#    - Determination of why solutions for connection problems are appropriate
# Course Name: Advanced Diploma in Medical Laboratory Technician (ADMLT) Course
# Course Link: https://www.henryharvin.com/advanced-diploma-in-medical-laboratory-technician-course
#
# Course Name: Advanced Diploma in Medical Laboratory Technician (ADMLT) Course
# Syllabus:
# 🔹 Module 1: COVID 19: General Awareness
#    - COVID 19- Introduction, epidemiology & Clinical features
#    - The DO’s and DON’ts to fight COVID - 19
#    - Whom to test for COVID - 19
#    - The right way to wear a mask
#    - The right kind of mask for you
#    - How to make mask at home
#    - Sanitization of masks
#    - How to effectively home - quarantine
#    - Taking care of the elderly during COVID- 19
#    - Don't hoard, don't rush
#    - Fighting social stigma
#    - Effective parenting tips during lockdown
#    - Sanitization at workplace during COVID
#    - COVID 19: Guidelines for school administrators, staff and teachers
#    - Quiz Module 1
#
#
# 🔹 Module 2: Medical Terminology
#    - Introduction to Medical terminology
#    - Anatomical Position
#    - Terminology related to body parts
#    - Parts of Medical Terminology
#    - Anatomical Planes
#    - Regional terms of the human body
#    - Directional Terms
#    - Diagnostic Suffixes
#    - Pathological Suffixes
#    - Surgical suffixes
#    - Grammatical Suffixes
#    - Prefixes of position and direction
#    - Prefixes of number and measurement
#    - Abbreviations & Symbols
#    - Medical terminology: Revision
#    - Quiz Module 2
#
#
# 🔹 Module 3: Revised anatomy and physiology
#    - Importance of Anatomy and Physiology
#    - Structural Level of organization
#    - Cell- structure, function
#    - Tissue
#    - Digestive system
#    - Respiratory System
#    - Skeletal System (Basic and Axial)
#    - Skeletal System: Appendicular system
#    - Skeletal system : Long bone and joints
#    - Muscular system
#    - Circulatory System
#    - Urinary System-Structural Aspects
#    - Urinary System- Functional Aspects
#    - Integumentary system
#    - Reproductive System - MALE
#    - Reproductive System - FEMALE
#    - Endocrine System Part I
#    - Endocrine System Part II
#    - Nervous System- CNS
#    - Nervous System-PNS
#    - Lymphatic System
#    - Body Fluids
#    - SFHB review test
#
#
# 🔹 Module 4: Infection control and biomedical waste management
#    - Importance of Infection control & Biomedical waste management
#    - Infection And its types
#    - Chain of Infection
#    - Chain of infection 2 (break the chain of infection)
#    - Infection Control
#    - Hand Hygiene
#    - Sterilization (Part 1)
#    - Vaccination for Health care workers (HCWs)
#    - NABH Norms - Hospital Infection Control
#    - Biomedical Waste Management ( Basic Introduction )
#    - Steps for Biomedical waste management
#    - Treatment and disposal of BMW
#    - PPE (Personal protective equipment)
#    - Quiz Module 4
#
#
# 🔹 Module 5: Medical Emergencies
#    - Importance Of basic medical emergency procedure
#    - Introduction- Basic medical emergency And life support skills
#    - Vital signs - Introduction and temperature
#    - Vital signs- Pulse, Respiratory rate
#    - Vital Signs: Blood pressure
#    - Pulse Oximeter
#    - Managing emergency
#    - BLS- Adult CPR
#    - CPR- Child
#    - Fractures
#    - Choking
#    - BURNS -Introduction and its types
#    - Burns - Management
#    - Haemorrhage (part 1)
#    - Haemorrhage (part 2)
#    - Haemorrhage (part 3)
#    - Wound and its Management (part - 1)
#    - Wound and its Management (part - 2)
#    - Medical emergency revision test
#    - Quiz Module 5
#
#
# 🔹 Module 6: Medical ethics and law
#    - Importance of medical law and ethics
#    - Medical Ethics
#    - Code of conduct
#    - Consent
#    - Medical Malpractice and Negligence
#    - Medico Legal Cases (MLCs)
#    - Medical law and ethics: Revision Test
#    - Quiz Module 6
#
#
# 🔹 Module 7: Basics of medical lab technician
#    - Medical laboratory technician : Basics
#    - Laboratory types and its personnels (Part 1)
#    - Laboratory types and its personnels (Part 2)
#    - Regulatory Agency (Part 1)
#    - Regulatory Agency (Part 2)
#
#
# 🔹 Module 8: Pre Analytical laboratory testing process
#    - Importance of laboratory tests
#    - Pre analytical testing process
#    - Sample collection and preservation
#    - Types of samples - part 1
#    - Types of samples - part 2
#    - collection method of samples other than blood samples - part 1 (Urine)
#    - collection method of samples other than blood samples - part 2 (Faeces sample)
#    - collection method of samples other than blood samples - part 3 (Sputum)
#    - collection method of samples other than blood samples - part 4 (Tissues, semen and CSF sample)
#    - Sample collection error
#    - sample labeling and documentation
#    - Sample handling
#    - Sample storage, retention and disposal
#    - sample transportation (Part 1)
#    - Sample Transportation (Part 2)
#    - Post analytical testing
#
#
# 🔹 Module 9: Basics of Hematology
#    - Introduction to hematology
#    - Blood and its components
#    - Complete blood Count (CBC)
#    - DLC
#    - Microscopic examination - DLC
#
#
# 🔹 Module 10: Hematology - Apparatus and procedures
#    - Types of samples - Part 1
#    - Types of samples - Part 2
#    - Blood collection system ( Part 1)
#    - Complications and Management for blood collection (Part 1)
#    - Haemocytometer (part - 1)
#    - Haemocytometer (part - 2)
#    - Haemoglobin estimation
#    - Apparatus used in haematology (Part 1)
#    - Apparatus used in haematology (Part 2)
#    - Pipette and pipetting techniques (Part 1)
#    - Pipette and Pipetting techniques (Part 2)
#    - Glassware used in laboratory (part 1)
#    - Glassware used in laboratory (part 2)
#
#
# 🔹 Module 11: Blood Banking
#    - Blood banking - Introduction
#    - Blood groups
#    - Blood typing
#    - Blood compatibility test
#    - Blood donation
#    - Blood storage and transportation
#    - Blood transfusion
#
#
# 🔹 Module 12: Immunology and serology
#    - Introduction - Immunology and serology
#    - Acquired immunity
#    - Immunity and its types
#    - Antigen
#    - Antibody
#    - Serological Test
#    - Autoimmunity and autoimmune disorders
#    - Human Immunodeficiency disease
#    - Antigen and antibody reaction
#    - Types of antigen - Antibody reaction (precipitation reaction)
#    - Types of antigen - Antibody reaction (Agglutination reaction and CFT)
#    - Types of Ag and ab reaction - immunofluorescence and ELISA
#
#
# 🔹 Module 13: Basics of Biochemistry
#    - Importance of biochemistry
#    - Basic Nutrients
#    - Carbohydrates
#    - Elementary knowledge of lipids - 1
#    - Elementary knowledge of lipids - 2
#    - Elementary knowledge of lipids - 3
#    - Proteins (Part 1)
#    - Proteins (Part 2)
#    - Proteins (Part 3)
#    - Revision - Clinical biochemistry
#    - Organ function tests - Kidney
#    - Organ function tests - Liver
#    - Acid Base balance
#    - Minerals and electrolytes
#    - Hormones (clinical significance)
#    - Hormones: Types
#    - Hormones (Basics)
#    - Clinical enzymology 2
#    - Clinical enzymology 1
#
#
# 🔹 Module 14: Clinical Pathology
#    - Importance of clinical pathology
#    - Urine examination
#    - Stool Examination
#    - Sputum Examination
#    - Semen Analysis
#    - CSF Examination
#    - Body cavity fluid analysis
#
#
# 🔹 Module 15: Basics of Microbiology
#    - Importance of basics of Microbiology
#    - basics of Microbiology
#    - morphology of bacteria-1
#    - morphology of bacteria _2
#    - BACTERIAL GROWTH
#    - CULTURE MEDIA _1
#    - CULTURE MEDIA _2
#    - BACTERIAL CULTIVATION
#    - COMMON STAINING METHODS _1
#    - COMMON STAINING METHODS _2
#    - MICROSCOPY
#    - BIOCHEMICAL TEST_1
#    - BIOCHEMICAL TEST_2
#
#
# 🔹 Module 16: .BASICS OF BACTERIOLOGY
#    - IMPORTANCE OF BACTERIOLOGY
#    - Staphylococcus basics
#    - Micrococci
#    - Streptococcus basics
#    - Pneumococcus
#    - Salmonella
#    - Shigella
#    - Hemophilus
#    - Mycobacterium
#
#
# 🔹 Module 17: .Basics of virology, mycology,parasitology
#    - importance of virology, ●mycology,and parasitology
#    - Virology, basics
#    - Guidelines for choice and handling of viral specimens-1
#    - Guidelines for the choice and handling of viral specimens _2
#    - mycology _1
#    - mycology _2
#    - diagnosis of fungal specimens _1
#    - diagnosis of fungal specimens _2
#    - Introduction to parasitology
#    - protozoa
#    - plasmodium
#    - helminths
#    - parasitology _miscellaneous
#
#
# 🔹 Module 18: basics of histopathology and cytopathology
#    - importance of histopathology
#    - History logical techniques
#    - Labeling and fixation 1,2
#    - Processing and embedding
#    - Microtomes
#    - Trimming and sectioning
#    - Collection of section
#    - Stainning and it’s type part 1 and 2
#    - Honing and Stropping
#    - Cytopathy part 1 and
#
#
# 🔹 Module 19: Advance Hematology
#    - Introduction to hematology
#    - erythropoiesis
#    - leucopoiesis
#    - thrombopoiesis
#    - Anticoagulant
#    - Red blood cell count -Haemocytometer
#    - WBC count - Methods
#    - Diffential Leukocyte count (DLC)-
#    - Morphology of White blood cells
#    - Reticulocyte count
#    - HB estimation method -Colorimetric method
#    - Clinical Importance
#    - ESR (Wintrobe & Westergren’s Method)
#    - Malaria,Polycythemia
#    - Bleeding Time and Clotting Time
#    - Absolute Eosinophil Count
#    - Staining Procedures
#
#
# 🔹 Module 20: Advance Clinical Pathology
#    - Urine Examination
#    - Physical Examination ,(Color,Turbidity,volume,Odour)
#    - Chemical Examination (Rohtera's, Benedict, Heat & Acetic Acid & Hey 's test)
#    - Preparation of Microscopic slide
#    - Microscopic Examination (RBCs,Pus cells,Crystals)
#    - Stool Examination
#    - physical Examination ,(Color,Consistency)
#    - Chemical Examination (, Benedict, Heat & Acetic Acid & Hey 's test)
#    - Preparation of Microscopic slide
#    - Microscopic Examination ( Presence of pus cells & Bacterial infection)
#    - Chemical Examination(Giemsa stain ,Proetin & Sugar)
#    - Physical Examination (Appearance)
#    - CSF Examionation
#    - Microscopy (Presence of Bacteria)
#    - Chemical Examination (AFB Staining )
#    - Prepation of Sputum Slide
#    - Physical Examination(Appearance)
#    - Sputum Examination
#    - Microscopic Examination(Morphology,Vitality,Sperm count)
#    - Chemical Examination (, PH & Semen Fructose Test)
#    - Physical Examination ,(Color,volume,Viscosity,Liquefaction,Turbidity)
#    - Semen Examination
#    - Stool Occult Blood test
#    - Microscopic Examination (RBCs,Pus cells,WBcs)
#
#
# 🔹 Module 21: Basics of Histopathology and Cytopathology
#    - Receipt & Identification
#    - Fixation
#    - Dehydration
#    - Clearing
#    - Impregnation
#    - Embedding
#    - Section cutting
#    - StainingMounting
#    - Examination Of Csf
#    - PAS & PAP staining principal and uses Theory of frozen section prep ration
#    - Stains for AFB [TB and leprosy]
#    - Theory of frozen section prep ration
#    - Examination Of Pleural Fluid
#    - Labelling of the specimen with numbering
#
#
# 🔹 Module 22: Immunological; Test
#    - VDRL
#    - ELISA
#    - RIA
#    - CRP
#    - WIDAL
#    - PCR,RT PCR
#    - ASO
#    - RA
#    - Typhidot IgG & IGM
#    - RUBELLA IGG& IGM
#
#
# 🔹 Module 23: BIOCHEMISTRY
#    - Liver Function Test
#    - kidney Function Test
#    - Lipid Profile
#    - Hormones- Role of biological Important hormones. Insulin glucose, epinephrine, thyroid growth hormones steroid hormones.
#    - Chemistry and biological role of vitamins (7hrs)
#    - Mineral metabolism iron, copper, calcium, magnesium, phosphorus sodium, potassium, chloride, iodine
#
#
# 🔹 Module 24: Complimentary Module 1: Soft Skills Development
#    - Business Communication
#    - Preparation for the Interview
#    - Presentation Skills
#
#
# 🔹 Module 25: Complimentary Module 2: Resume Writing
#    - Resume Writing
# Course Name: Aerodynamics Course
# Course Link: https://www.henryharvin.com/aerodynamics-course
#
# Course Name: Aerodynamics Course
# Syllabus:
# 🔹 Module 1: Introduction to Aerodynamics
#    Understand the basic principles of aerodynamics Learn about the different types of aerodynamics problems Develop an understanding of the role of aerodynamics in different applications
#    - Fundamentals of Aerodynamics
#    - Types of Aerodynamics Problems
#    - Applications of Aerodynamics
#
#
# 🔹 Module 2: Fluid Mechanics
#    Understand the basics of fluid mechanics Learn about the different types of fluids and their properties Develop an understanding of the role of fluid mechanics in aerodynamics
#    - Introduction to Fluid Mechanics
#    - Types of Fluids and their Properties
#    - Role of Fluid Mechanics in Aerodynamics
#
#
# 🔹 Module 3: Airfoil Theory
#    Understand the basics of airfoil theory Learn about the different types of airfoils and their properties Develop an understanding of the role of airfoil theory in aerodynamics
#    - Introduction to Airfoil Theory
#    - Types of Airfoils and their Properties
#    - Role of Airfoil Theory in Aerodynamics
#
#
# 🔹 Module 4: Wing Theory
#    Understand the basics of wing theory Learn about the different types of wings and their properties Develop an understanding of the role of wing theory in aerodynamics
#    - Introduction to Wing Theory
#    - Types of Wings and their Properties
#    - Role of Wing Theory in Aerodynamics
#
#
# 🔹 Module 5: Boundary Layer Theory
#    Understand the basics of boundary layer theory Learn about the different types of boundary layers and their properties Develop an understanding of the role of boundary layer theory in aerodynamics
#    - Introduction to Boundary Layer Theory
#    - Types of Boundary Layers and their Properties
#    - Role of Boundary Layer Theory in Aerodynamics
#
#
# 🔹 Module 6: Compressible Flow
#    Understand the basics of compressible flow Learn about the different types of compressible flows and their properties Develop an understanding of the role of compressible flow in aerodynamics
#    - Introduction to Compressible Flow
#    - Types of Compressible Flows and their Properties
#    - Role of Compressible Flow in Aerodynamics
#
#
# 🔹 Module 7: Supersonic Flow
#    Understand the basics of supersonic flow Learn about the different types of supersonic flows and their properties Develop an understanding of the role of supersonic flow in aerodynamics
#    - Introduction to Supersonic Flow
#    - Types of Supersonic Flows and their Properties
#    - Role of Supersonic Flow in Aerodynamics
#
#
# 🔹 Module 8: Aerodynamic Design
#    Understand the basics of aerodynamic design Learn about the different approaches to aerodynamic design Develop an understanding of how to apply aerodynamic design principles to real-world problems
#    - Introduction to Aerodynamic Design
#    - Approaches to Aerodynamic Design
#    - Application of Aerodynamic Design Principles to Real-World Problems
#
#
# 🔹 Module 9: Aerodynamic Testing
#    Understand the basics of aerodynamic testing Learn about the different types of aerodynamic testing methods Develop an understanding of how to interpret aerodynamic test results
#    - Introduction to Aerodynamic Testing
#    - Types of Aerodynamic Testing Methods
#    - Interpretation of Aerodynamic Test Results
#
#
# 🔹 Module 10: Flight Dynamics
#    Understand the basics of flight dynamics Learn about the different types of aircraft motion and their characteristics Develop an understanding of how aerodynamics affects aircraft motion
#    - Introduction to Flight Dynamics
#    - Types of Aircraft Motion and their Characteristics
#    - Aerodynamics and Aircraft Motion
#
#
# 🔹 Module 11: Aircraft Stability and Control
#    Understand the basics of aircraft stability and control Learn about the different types of stability and control systems Develop an understanding of how aerodynamics affects stability and control
#    - Introduction to Aircraft Stability and Control
#    - Types of Stability and Control Systems
#    - Aerodynamics and Stability and Control
#
#
# 🔹 Module 12: Aircraft Performance
#    Understand the basics of aircraft performance Learn about the different types of aircraft performance parameters Develop an understanding of how aerodynamics affects aircraft performance
#    - Introduction to Aircraft Performance
#    - Types of Aircraft Performance Parameters
#    - Aerodynamics and Aircraft Performance
#
#
# 🔹 Module 13: Wing Design and Optimization
#    Understand the basics of wing design and optimization Learn about the different approaches to wing design and optimization Develop an understanding of how to apply wing design and optimization principles to real-world problems
#    - Introduction to Wing Design and Optimization
#    - Approaches to Wing Design and Optimization
#    - Application of Wing Design and Optimization Principles to Real-World Problems
#
#
# 🔹 Module 14: Turbulence Modeling
#    Understand the basics of turbulence modeling Learn about the different types of turbulence models and their properties Develop an understanding of how to use turbulence models in computational fluid dynamics (CFD) simulations
#    - Introduction to Turbulence Modeling
#    - Types of Turbulence Models and their Properties
#    - Application of Turbulence Models in CFD Simulations
#
#
# 🔹 Module 15: Hypersonic Flow
#    Understand the basics of hypersonic flow Learn about the different types of hypersonic flows and their properties Develop an understanding of the challenges of hypersonic flight and how to address them
#    - Introduction to Hypersonic Flow
#    - Types of Hypersonic Flows and their Properties
#    - Challenges of Hypersonic Flight and their Solutions
#
#
# 🔹 Module 16: Aeroelasticity
#    Understand the basics of aeroelasticity Learn about the different types of aeroelastic phenomena Develop an understanding of how to analyze and design for aeroelasticity
#    - Introduction to Aeroelasticity
#    - Types of Aeroelastic Phenomena
#    - Analysis and Design for Aeroelasticity
#
#
# 🔹 Module 17: Computational Fluid Dynamics (CFD)
#    Understand the basics of computational fluid dynamics (CFD) Learn about the different types of numerical methods used in CFD Develop an understanding of how to use CFD software to solve aerodynamic problems
#    - Introduction to CFD
#    - Numerical Methods used in CFD
#    - Using CFD Software to Solve Aerodynamic Problems
#
#
# 🔹 Module 18: Wind Tunnel Testing
#    Understand the basics of wind tunnel testing Learn about the different types of wind tunnels and their properties Develop an understanding of how to design and conduct wind tunnel tests
#    - Introduction to Wind Tunnel Testing
#    - Types of Wind Tunnels and their Properties
#    - Design and Conduct of Wind Tunnel Tests
#
#
# 🔹 Module 19: Propulsion Systems
#    Understand the basics of aircraft propulsion systems Learn about the different types of propulsion systems and their properties Develop an understanding of how aerodynamics affects propulsion systems
#    - Introduction to Aircraft Propulsion Systems
#    - Types of Propulsion Systems and their Properties
#    - Aerodynamics and Propulsion Systems
#
#
# 🔹 Module 20: Flow Control
#    Understand the basics of flow control Learn about the different types of flow control techniques Develop an understanding of how to apply flow control to improve aerodynamic performance
#    - Introduction to Flow Control
#    - Types of Flow Control Techniques
#    - Application of Flow Control to Improve Aerodynamic Performance
#
#
# 🔹 Module 21: Aeroacoustics
#    Understand the basics of aeroacoustics Learn about the different types of noise generated by aerodynamic flows Develop an understanding of how to reduce aerodynamic noise
#    - Introduction to Aeroacoustics
#    - Types of Noise Generated by Aerodynamic Flows
#    - Reduction of Aerodynamic Noise
#
#
# 🔹 Module 22: Aircraft Design
#    Understand the basics of aircraft design Learn about the different types of design considerations for aircraft Develop an understanding of how to apply design principles to real-world problems
#    - Introduction to Aircraft Design
#    - Design Considerations for Aircraft
#    - Application of Design Principles to Real-World Problems
#
#
# 🔹 Module 23: Flow Visualization
#    Understand the basics of flow visualization Learn about the different types of flow visualization techniques Develop an understanding of how to use flow visualization to understand aerodynamic flows
#    - Introduction to Flow Visualization
#    - Types of Flow Visualization Techniques
#    - Using Flow Visualization to Understand Aerodynamic Flows
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Course Link: https://www.henryharvin.com/animation-pro-course
#
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Syllabus:
# Syllabus not available
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Course Link: https://www.henryharvin.com/animation-vfx-pro-course
#
# Course Name: WHY CHOOSE HENRY HARVIN® ANIMATION ACADEMY?
# Syllabus:
# Syllabus not available
# Course Name: PREMIUM AVIATION COURSES
# Course Link: https://www.henryharvin.com/aviation-tourism-hopitality-professional-course
#
# Course Name: PREMIUM AVIATION COURSES
# Syllabus:
# Syllabus not available
# Course Name: Biological Anthropology Course
# Course Link: https://www.henryharvin.com/biological-anthropology-course
#
# Course Name: Biological Anthropology Course
# Syllabus:
# 🔹 Module 1: Introduction to Biological Anthropology
#    Understand the definition and scope of biological anthropology Learn about the history and key figures of the field Understand the interdisciplinary nature of biological anthropology
#    - Definition and Scope of Biological Anthropology
#    - History of Biological Anthropology
#    - Interdisciplinary Nature of Biological Anthropology
#
#
# 🔹 Module 2: Human Evolution
#    Understand the principles of evolution Learn about the major events in human evolution Understand the fossil record and how it informs our understanding of human evolution
#    - Principles of Evolution
#    - Major Events in Human Evolution
#    - Fossil Record in Human Evolution
#
#
# 🔹 Module 3: Genetics and Human Variation
#    Understand the principles of genetics Learn about the genetic basis of human variation Understand how genetics and environment interact to shape human variation
#    - Principles of Genetics
#    - Genetic Basis of Human Variation
#    - Genetics-Environment Interactions in Human Variation
#
#
# 🔹 Module 4: Primatology
#    Understand the principles of primatology Learn about the behavior and social organization of primates Understand the relationship between primates and humans
#    - Principles of Primatology
#    - Behavior and Social Organization of Primates
#    - Primate-Human Relationship
#
#
# 🔹 Module 5: Skeletal Biology and Osteology
#    Understand the principles of skeletal biology and osteology Learn about the skeletal system and bone structure Understand how the skeletal system informs our understanding of human biology and evolution
#    - Principles of Skeletal Biology and Osteology
#    - Skeletal System and Bone Structure
#    - Skeletal System in Human Biology and Evolution
#
#
# 🔹 Module 6: Forensic Anthropology
#    Understand the principles of forensic anthropology Learn about the role of forensic anthropology in criminal investigations Understand how skeletal remains are used to determine age, sex, and ancestry
#    - Principles of Forensic Anthropology
#    - Role of Forensic Anthropology in Criminal Investigations
#    - Determining Age, Sex, and Ancestry from Skeletal Remains
#
#
# 🔹 Module 7: Human Growth and Development
#    Understand the principles of human growth and development Learn about the physical and cognitive changes that occur across the lifespan Understand how these changes are influenced by genetics and environment
#    - Principles of Human Growth and Development
#    - Physical and Cognitive Changes Across the Lifespan
#    - Genetics and Environment in Human Growth and Development
#
#
# 🔹 Module 8: Dental Anthropology
#    Understand the principles of dental anthropology, Learn about dental anatomy and tooth development, Understand how dental characteristics are used to determine age, sex, and ancestry
#    - Principles of Dental Anthropology
#    - Dental Anatomy and Tooth Development
#    - Determining Age from Dental Characteristics
#    - Determining Sex from Dental Characteristics
#    - Determining Ancestry from Dental Characteristics
#    - Dental Anthropology in Biological and Forensic Anthropology
#    - Dental Anthropology in Archaeological Investigations
#    - Dental Anthropology and Biomedical Research
#    - Dental Pathology and Health
#    - Dental Occlusion and Malocclusion
#    - Dental Anthropology and Evolutionary Biology
#    - Dental Anthropology and Human Diversity
#
#
# 🔹 Module 9: Human Biocultural Adaptations
#    Understand the concept of biocultural adaptation Learn about the ways in which humans have adapted to their environments Understand the role of culture in shaping human biology and behavior
#    - Concept of Biocultural Adaptation
#    - Human Adaptations to Different Environments
#    - Culture and Human Biology/Behavior
#
#
# 🔹 Module 10: Anthropological Archaeology
#    Understand the principles of anthropological archaeology Learn about the methods used in archaeological research Understand the role of archaeology in reconstructing human history and evolution
#    - Principles of Anthropological Archaeology
#    - Archaeological Research Methods
#    - Archaeology in Reconstructing Human History and Evolution
#
#
# 🔹 Module 11: Biological Anthropology and Public Health
#    Understand the connection between biological anthropology and public health Learn about the ways in which biological anthropology informs public health policies and interventions Understand the importance of cultural competence in public health practice
#    - Connection between Biological Anthropology and Public Health
#    - Biological Anthropology and Public Health Interventions
#    - Cultural Competence in Public Health Practice
#
#
# 🔹 Module 12: Human Migration and Dispersal
#    Understand the principles of human migration and dispersal Learn about the different theories and models of human migration Understand the genetic and cultural consequences of human migration
#    - Principles of Human Migration and Dispersal
#    - Theories and Models of Human Migration
#    - Genetic and Cultural Consequences of Human Migration
#
#
# 🔹 Module 13: Primate Evolution and Conservation
#    Understand the principles of primate evolution and conservation Learn about the threats to primate populations and their habitats Understand the role of conservation efforts in primate preservation
#    - Principles of Primate Evolution and Conservation
#    - Threats to Primate Populations and Habitats
#    - Conservation Efforts in Primate Preservation
#
#
# 🔹 Module 14: Human Behavioral Ecology
#    Understand the principles of human behavioral ecology Learn about the ecological and social factors that shape human behavior Understand the relationship between human behavior and reproductive success
#    - Principles of Human Behavioral Ecology
#    - Ecological and Social Factors in Human Behavior
#    - Human Behavior and Reproductive Success
#
#
# 🔹 Module 15: Human Skeletal Growth and Development
#    Understand the principles of human skeletal growth and development Learn about the factors that influence skeletal growth and development Understand how skeletal development is used to determine age in forensic and archaeological contexts
#    - Principles of Human Skeletal Growth and Development
#    - Factors Influencing Skeletal Growth and Development
#    - Skeletal Development and Age Determination
#
#
# 🔹 Module 16: Human Adaptations to Disease
#    Understand the principles of coevolution between humans and pathogens, Identify the genetic and immunological factors that influence disease susceptibility and resistance, Explore the cultural and behavioral adaptations that humans have developed to cope with infectious diseases
#    - Coevolutionary Theory of Infectious Disease
#    - Genetic Adaptations to Infectious Disease
#    - Immunological Adaptations to Infectious Disease
#    - Cultural Adaptations to Infectious Disease
#    - Behavioral Adaptations to Infectious Disease
#    - Epidemiology and Disease Ecology
#    - Human-Pathogen Interactions and Disease Dynamics
#    - Public Health Implications of Human Adaptations to Disease
#
#
# 🔹 Module 17: Human Evolutionary Genetics
#    Understand the principles of human evolutionary genetics Learn about the genetic evidence for human evolution Understand the implications of human genetic diversity for health and disease
#    - Principles of Human Evolutionary Genetics
#    - Genetic Evidence for Human Evolution
#    - Human Genetic Diversity and Health/Disease
#
#
# 🔹 Module 18: Primatology
#    Understand the principles of primatology Learn about the behavior and ecology of different primate species Understand the role of primatology in understanding human evolution and behavior
#    - Principles of Primatology
#    - Behavior and Ecology of Different Primate Species
#    - Primatology and Understanding Human Evolution/Behavior
#
#
# 🔹 Module 19: Human Nutrition and Evolution
#    Understand the principles of human nutrition and evolution Learn about the ways in which human diet has evolved over time Understand the implications of modern diets for human health and disease
#    - Principles of Human Nutrition and Evolution
#    - Evolution of Human Diet
#    - Modern Diets and Human Health/Disease
#
#
# 🔹 Module 20: Anthropology of Health and Illness
#    Understand the principles of the anthropology of health and illness Learn about the ways in which culture shapes health and illness beliefs and practices Understand the importance of cultural competence in healthcare delivery
#    - Principles of the Anthropology of Health and Illness
#    - Culture and Health/Illness Beliefs and Practices
#    - Cultural Competence in Healthcare Delivery
#
#
# 🔹 Module 21: Forensic Anthropology
#    Understand the principles of forensic anthropology Learn about the methods used in forensic anthropology investigations Understand the role of forensic anthropology in identifying human remains
#    - Principles of Forensic Anthropology
#    - Methods in Forensic Anthropology Investigations
#    - Identification of Human Remains
#
#
# 🔹 Module 22: Human Brain Evolution
#    Understand the principles of the anthropology of health and illness Learn about the ways in which culture shapes health and illness beliefs and practices Understand the importance of cultural competence in healthcare delivery
#    - Principles of Human Brain Evolution
#    - Evidence for Brain Evolution in the Fossil Record
#    - Brain Evolution and Human Behavior/Cognition
#
#
# 🔹 Module 23: Biological Anthropology and Ethics
#    Understand the ethical considerations in biological anthropology research Learn about the principles of informed consent and confidentiality in research Understand the implications of biological anthropology research for human rights and social justice
#    - Ethical Considerations in Biological Anthropology Research
#    - Informed Consent and Confidentiality in Research
#    - Biological Anthropology Research and Human Rights/Social Justice
#
#
# 🔹 Module 24: Human Dental Anthropology
#    Understand the principles of human dental anthropology, Learn about the ways in which teeth provide information about diet and behavior, Understand the role of dental anthropology in forensic and archaeological investigations
#    - Principles of Human Dental Anatomy
#    - Dental Development and Eruption
#    - Tooth Morphology and Function
#    - Dental Microwear and its Interpretation
#    - Dental Pathology and Health
#    - Dental Anthropology in Forensic Investigations
#
#
# 🔹 Module 25: Primate Evolution
#    Understand the evolutionary history of primates, Identify key morphological and behavioral adaptations that distinguish primates from other mammals
#    - Early primate evolution
#    - Adaptive radiation of primates
#    - Human evolution and primate diversity
#
#
# 🔹 Module 26: Forensic Anthropology
#    Understand the role of forensic anthropology in medico-legal investigations, Identify skeletal remains and estimate age, sex, and ancestry
#    - Basics of forensic anthropology
#    - Osteology and bone identification
#    - Analysis of skeletal remains
#
#
# 🔹 Module 27: Ethnobiology
#    Understand how different cultures interact with their environment and the living organisms within it, Identify the importance of traditional ecological knowledge and its conservation
#    - Traditional ecological knowledge
#    - Human-plant interactions
#    - Human-animal interactions
# Course Name: Business Journalism Course
# Course Link: https://www.henryharvin.com/business-journalism-course
#
# Course Name: Business Journalism Course
# Syllabus:
# 🔹 Module 1: What is Business Journalism?
#    Learn to continously monitor the business events and familiarize with the business styles of communication, to understand various levels of organizational communication
#    - Definition, Ethics and scope of business journalism
#    - Role and qualifications of a business reporter
#
#
# 🔹 Module 2: Business Journalism tools
#    Gain knowledge on business vocabulary and grammar, Learn to make business content with brevity and clarity
#    - Tools of Business meets
#    - Use of social networking sites in business
#    - Structure and content of Business journals
#
#
# 🔹 Module 3: Types of Business Reporting
#    Learn to categorize types of reporting according to the areas related, learn the business jargons like Chamber of Commerce, foreign direct investment, Corporate Social Responsibility
#    - Business Reporting categories and new trends
#    - Business terms
#
#
# 🔹 Module 4: Business Newspapers and publications
#    Equip students to start reading business newpapers and magazines, Learn to write error-free business reports and articles
#    - Economic Times, Business Line, Financial Express
#    - Business India, Business Today
# Course Name: CAT Preparation Course & Online Coaching
# Course Link: https://www.henryharvin.com/cat-preparation-course
#
# Course Name: CAT Preparation Course & Online Coaching
# Syllabus:
# 🔹 Quantitative Aptitude Syllabus
#    The Quantitative aptitude section of the CAT exam covers number systems, profit, loss, discount, LCM, HCF, etc
#    - Number Systems
#    - Profit, loss, and discount
#    - LCM and HCF
#    - Speed, Time, and Distance
#    - Percentages
#    - Time and Work
#    - Ratio and Proportion
#    - Averages
#    - Quadratic Equations & Linear Equations
#    - Complex Numbers
#    - Simple and Compound Interest
#    - Logarithm
#    - Sequences and Series
#    - Inequalities
#
#
# 🔹 Data Interpretation and Logical Reasoning Syllabus
#    - Tables
#    - Caselets
#    - Bar Graphs
#    - Line Graphs
#    - Column Graphs
#    - Venn Diagrams
#    - Pie Chart
#    - Other Basic Reasoning Questions
#    - Calendars
#    - Number and Letter Series
#
#
# 🔹 Verbal Reasoning Syllabus
#    The Verbal Reasoning syllabus has chapters on English usage or Grammar, Vocabulary based, Fill in the blanks, sentence correction, Cloze passage, etc
#    - English Usage or Grammar
#    - Vocabulary Based (Synonyms/Antonyms)
#    - Fill in the blank
#    - Sentence Correction
#    - Cloze Passage
#    - Jumbled Paragraph
#    - Meaning-usage Match
#    - Analogies & Reverse Analogies
#
#
# 🔹 Complimentary Module 1: Soft Skills Development
#    - Business Communication
#    - Preparation for the interview
#    - Presentation Skills.
#
#
# 🔹 Complimentary Module2: Resume Writing
#    - Resume Writing
# Course Name: Canada Visa Training Course
# Course Link: https://www.henryharvin.com/canada-visa-training-course
#
# Course Name: Canada Visa Training Course
# Syllabus:
# 🔹 Module 1: Introduction to Canadian Immigration
#    - Overview of Immigration Policies and History
#    - Evolution of Canadian immigration laws
#    - Current immigration landscape
#
#
# 🔹 Module 2: Types of Visas and Permits
#    - Temporary vs. permanent residency.
#    - Student Visa
#    - Work Visa
#    - L1 Visa
#    - L2 Visa
#    - B2 Visa
#    - E tourist Visa
#    - F1 Visa
#    - Research Visa
#    - Business Visa
#    - Employment Visa
#    - Journalist Visa
#    - Missionary Visa
#    - M1 Student Visa
#    - Project Visa
#    - Travel Visa
#
#
# 🔹 Module 3: Visa Categories and Eligibility
#    - Express Entry System
#    - Federal Skilled Worker Program
#    - Federal Skilled Trades Program
#    - Canadian Experience Class
#    - Family Sponsorship
#    - Eligibility criteria for sponsors and sponsored individuals
#    - Processing times and required documentation
#    - Study and Work Permits
#    - Student Direct Stream (SDS)
#    - Post-Graduation Work Permit (PGWP)
#    - Labour Market Impact Assessment (LMIA) process
#
#
# 🔹 Module 4: Application Procedures
#    - Document Preparation
#    - Gathering and verifying required documents (e.g., educational credentials, work experience letters)
#    - Translating and notarizing documents
#    - Form Completion and Submission
#    - Digital Application Process
#
#
# 🔹 Module 5: Legal and Regulatory Framework
#    - Canadian Immigration and Refugee Protection Act (IRPA)
#    - Key sections relevant to visa applications
#    - Immigration Regulations and Policies
#    - Recent changes and updates in immigration laws
#    - Rights and Responsibilities of Immigrants
#    - Legal rights upon arrival in Canada
#    - Obligations while on different types of visas
#
#
# 🔹 Module 6: Visa Status
#    - Visa Verification
#    - Visa Application Process
#    - Visa Renewal
#    - Visa on Arrival
#    - E visa
#    - Visa Requirements for India
#    - Visa Refusal
#    - Visa Waiver Programme
# Course Name: Car Designing Course
# Course Link: https://www.henryharvin.com/car-designing-course
#
# Course Name: Car Designing Course
# Syllabus:
# 🔹 Module 1: Automotive Design Basics
#    In this module learners will learn the basics of car designing
#    - Introduction
#    - What is Car Design
#    - Quiz Module 1
#
#
# 🔹 Module 2: Car Design Secrets5 Topics
#    This module will help learners to understand car design secrets
#    - Proportions and Vehicle types
#    - Perspective
#    - Side View
#    - Front & Rear 3/4 view
#    - Tip up view
#    - Quiz Module 2
#
#
# 🔹 Module 3: Sketching and Drawing5 Topics
#    In this module, learners will learn about sketching and drawings
#    - Tools you can use
#    - Line quality
#    - Line weight
#    - Focal Point
#    - Shading
#    - Quiz Module 3
#
#
# 🔹 Module 4: Sketching Cars3 Topics
#    In this module learners will learn all about sketching car design
#    - Side View
#    - Front 3/4 view
#    - Any other view
#    - Quiz Module 4
#
#
# 🔹 Module 5: The Interior of the Car4 Topics
#    This module will help learners gain understanding of the interior of the car
#    - Introduction
#    - Promo
#    - Overview
#    - Equipment
#    - Quiz Module 5
#
#
# 🔹 Module 6: Instrument Panel of Interior2 Topics
#    In this module, learners will learn about instruments panel of interior
#    - Instrumental Panel Part -1
#    - Instrumental Panel Part -2
#    - Quiz Module 6
#
#
# 🔹 Module 7: Interior Layout6 Topics
#    This module will teach learners about the interior layouts
#    - Quick Layout
#    - Instrument Panel
#    - Center Console
#    - Seating
#    - Steering Wheel
#    - Detailing
#    - Quiz Module 7
#
#
# 🔹 Module 8: Seating2 Topics
#    In this module, learn all about the concept, rules and regulations of seating
#    - Seating Part -1
#    - Seating Part -2
#    - Quiz Module 8
#
#
# 🔹 Module 9: Introduction of Adobe Illustrator3 Topics
#    In this module, learners will get introduced to adobe illustrator topics
#    - Introduction to Adobe Illustrator Interface
#    - Properties Tab of the Adobe Illustrator
#    - Pen tool Practice
#    - Quiz Module 9
#
#
# 🔹 Module 10: Car Rim Design Explanation 1 Topics
#    In this module, learners will gain understanding on the concepts of car rim design
#    - Anatomy of a Car
#    - Quiz Module 10
#
#
# 🔹 Module 11: Spoke Division on a Car Rim1 Topic
#    In this module, gain knowledge of spoke division on a car rim
#    - Spoke division on a Car Rim
#    - Quiz Module 11
#
#
# 🔹 Module 12: Car Rim Design Process2 Topics
#    This module will teach learners about the car rim design process
#    - Drawing Car Rim (Draft/Orthogonal View)
#    - Drawing Car Rim (2-point perspective View)
#    - Quiz Module 12
#
#
# 🔹 Module 13: Introduction to Automotive Design5 Topics
#    In this module, get introduced to automotive design topics
#    - Emotion and Flow: Secrets of Car Designer Line Quality
#    - Get Inspired: Developing Your Style and Technique with Speed Forms
#    - Master Your Wheels: Secrets of Drawing Circles
#    - Talk the Talk: The Vocabulary of Automotive Design
#    - In the Beginning: Secrets of Drawing Great Side Views
#    - Quiz Module 13
#
#
# 🔹 Module 14: Automotive Design5 Topics
#    This module will help learners gain a broader understanding of automotive design
#    - Coming and Going: Secrets of Drawing great front and rear view
#    - A view from the top: Secrets of Drawing a tip-up view
#    - Toward the Within: Introduction to Interior
#    - In a Brilliant Light: Understanding lights and shadows
#    - Shine Like it Does: Understanding Reflections
#    - Quiz Module 14
# Course Name: Certificate Course in Science Journalism
# Course Link: https://www.henryharvin.com/certificate-course-in-science-journalism
#
# Course Name: Certificate Course in Science Journalism
# Syllabus:
# 🔹 Module 1: Introduction to Science Communication
#    Gives awareness and understanding of the background, basics and theory of traditional and emerging media and how these relate to the communication of science
#    - Concept and Definition
#    - Science for the Society
#    - Science movements
#
#
# 🔹 Module 2: Writing for Science and Technology
#    Learns Science Communication jargons and to write for develops skills of intellectual analysis and independent research, and prepare them for a wide range of professional science communication careers
#    - Writing for Science and Technology-techniques, sources
#    - Science Reporting careers and Qualifications
#
#
# 🔹 Module 3: Science in Media
#    Familiarize Science supplements in Indian newspapers and read them on a daily basis, Form a habit of watching scientific reports appearing on TV, magazines, and newspapers
#    - Science magazines-Intro
#    - Science Channels-History and Strategies
#
#
# 🔹 Module 4: Science Journalism-Detailed Outlook
#    Students will learn to appreciate the scope and diversity of science communication,Be confident to take seminars and presentations on related topics of Science Journalism
#    - Ethics of Science Journalism
#    - Interview: Science Reporter-Practical
#
#
# 🔹 Module 5: Science Organizations-Overview
#    Learn to eradicate the unscientific ideas from the society, to create innovative ideas to make positive changes in the over all areas of Science and technology
#    - NCSTC, NCSM, NISCAIR
#    - ISCOS,ICMR
# Course Name: Certified Professional in Cabin Crew Course
# Course Link: https://www.henryharvin.com/certified-professional-in-cabin-crew-course
#
# Course Name: Certified Professional in Cabin Crew Course
# Syllabus:
# 🔹 Module 1: Introduction to the Aviation industry
#    - Introduction to the aviation industry and aviation regulations
#    - Airport and airline organization and structure
#    - Regulatory Context of the airline industry
#    - Aircraft types, configurations, and systems
#
#
# 🔹 Module 2: Aviation operations
#    - Airport and passenger processing
#    - Flight operation
#    - The aircraft cabin
#    - Theory of Flight and altitude physiology
#    - Flight planning and navigation
#    - Meteorological factors affecting aviation operations
# ...
#    - Customer Reporting
#    - Write off bad DEBT
#    - Cash sales
#    - Record customer payment with an on-account Amount
#    - Deposit customer payments
#    - Record Cash Sales
#    - Modify the cash sales BP
#    - Receivable aging report
#    - Customer statements
#    - Receivables Aging Reports
#    - Customer Statements
#    - Quiz Module 9
#
#
# 🔹 Module 10: Financial Common Report
#    - Workday Standard report
#    - Standard vs espresso report
#    - Run standard and espresso report
#    - Event accounting summary report
#    - Balance By Bank Report
#    - Trial balance Report
#    - Ledger detail report
#    - Ledger account activity summary report
#    - Ledger year beginning balance report
#    - Find journal
#    - Find customer
#    - Find customer invoice
#    - Find customer payment
#    - Settlement report
#    - Quiz Module 10
# Course Name: Data Science Professional Course
# Course Link: https://www.henryharvin.com/data-science-certification
#
# Course Name: Data Science Professional Course
# Syllabus:
# 🔹 Module 1: Introduction to Data Science
#    In this module the candidate will learn about Data Science, which includes understanding Data Analysis in Excel and Analytics Problem Solving
#    - Understanding Data Science
#    - Data Analysis in Excel
#    - Analytics Problem Solving
#    - Quiz Module 1
#
#
# 🔹 Module 2: Introduction to python Exploratory
#    In this module the candidate will learn about Python Exploratory, which includes understanding of Data Tool-Kit Data Analysis using SQL, an overview of Python Exploratory and Data Analysis Inferential Statistics Hypothesis Testing
#    - Data Tool-Kit Data Analysis using SQL
#    - Introduction to Python Exploratory
#    - Data Analysis Inferential Statistics Hypothesis Testing
#    - Quiz Module 2
#
#
# 🔹 Module 3: Getting And Cleaning Data
#    In this module the candidate will learn about Cleaning and Getting Data, which includes understanding Components of complete Data Set - Raw Data, Codebooks and learning how to collect, clean and share data
#    - Components of complete Data Set - Raw data, codebooks
#    - How to collect, clean and share data
#    - Quiz Module 3
#
#
# 🔹 Module 4: Exploratory Data Analsis, Research and Statistical Inference
#    In this module the candidate will learn about Exploratory Data Analysis which includes understanding Multivariate Statistical Techniques, knowing various plotting systems in different languages, learning different Statistical Analysis tools, Publishing Data Analysis and understanding how to make informed and accurate decisions
#    - Understanding multivariate statistical techniques
#    - Know various plotting systems in different programming languages
#    - Learn different statistical analysis tools
#    - How to publish Data Analysis
#    - How to take informed and accurate decisions
#    - Quiz Module 4
#
#
# 🔹 Module 5: Regression Models and Practical Machine Learning
#    In this module the candidate will learn about Regression Models, which includes Model Selection and Novel uses of Regression models, Building Prediction Functions and Applying Algorithms and learning how to do evaluation
#    - Model selection and novel uses of regression models
#    - Building prediction functions — Data collection, feature creation
#    - How to apply Algorithms and learning how to do evaluation
#    - Quiz Module 5
# Course Name: Dual Degree in MCA Data Analytics + Data Science Course
# Course Link: https://www.henryharvin.com/mca-data-analytics-data-science-course
#
# Course Name: Dual Degree in MCA Data Analytics + Data Science Course
# Syllabus:
# 🔹 Course 1: MCA Data Analytics
#
# 📌 Semester 1
#    - Mathematical Foundation for Computer Application
#    - Operating System and Unix Shell Programming
#    - Data Communication and Computer Networks
#    - Data Structures with Algorithms
#    - Computer Organisation and Architecture
#
# 📌 Semester 2
#    - Relational Database Management System
#    - Design and Analysis of Algorithms
#    - R Programming
#    - Python Programming
#    - Structured Query Language
#
# 📌 Semester 3
#    - Application Development using Python
#    - Advanced Web Technologies
#    - Machine Learning
#    - Natural Language Processing
#    - Internet of Things
#    - Open Elective Course
#
# 📌 Semester 4
#    - Big Data - Hadoop
#    - Artificial Intelligence
#    - Deep Learning
#    - Computer Vision
#    - Cross-Functional Elective Course
#    - Project
#
#
# 🔹 Course 2: Data Science
#
# 📌 Module 1: Introduction to Data Science
#    - Understanding Data Science
#    - Data Analysis in Excel
#    - Analytics Problem Solving
#
# 📌 Module 2: Introduction to python Exploratory
#    - Data Tool-Kit Data Analysis using SQL
#    - Introduction to Python Exploratory
#    - Data Analysis Inferential Statistics Hypothesis Testing
#
# 📌 Module 3: Getting And Cleaning Data
#    - Components of complete Data Set - Raw data, codebooks
#    - How to collect, clean and share data
#
# 📌 Module 4: Exploratory Data Analysis, Research, and Statistical Inference
#    - Understanding multivariate statistical techniques
#    - Know various plotting systems in different programming languages
#    - Learn different statistical analysis tools
#    - How to publish Data Analysis
#    - How to take informed and accurate decisions
#
# 📌 Module 5: Regression Models and Practical Machine Learning
#    - Model selection and novel uses of regression models
#    - Building prediction functions — Data collection, feature creation
#    - How to apply Algorithms and learning how to do evaluation
#
#
# 🔹 Complimentary Module 1: Soft Skills Development
#    - Business Communication
#    - Preparation for the Interview
#    - Presentation Skills
#
#
# 🔹 Complimentary Module 2: Resume Writing
#    Resume Writing
# Course Name: French Language Course for Kids
# Course Link: https://www.henryharvin.com/french-language-course-for-kids
#
# Course Name: French Language Course for Kids
# Syllabus:
# 🔹 Level: A1
#
# 📌 Topics
#    - Alphabet
#    - Counting
#    - Fruits & Vegetables
#    - Salutations
#    - Colors
#    - Classroom Objects
#    - What is this? Who is this?
#    - Say what is one doing
#    - Expressing your likes and dislikes Days of the weeks and months of the year
#    - Directions & Prepositions
#    - Where do you live?
#    - My House & Room
#    - Family
#    - Animals & Birds
#    - Verbs & Sentence Structure
#    - Write a Post Card
#    - Body Parts
#    - Describe yourself and Someone
#    - Picnic
#    - Foods & Drinks
#    - Clothes
#    - Seasons & Weather
#    - Festivals
#    - Means of Transport
#    - Listening, Speaking Writing & Reading Activities
#    - French SOngs and Puppet Shows
#    - Number (21 to 100)
#    - Time
#    - Country, Nationality & Language
#    - Subjects
#    - Describing Someone
#    - Classroom Activities
#    - Shops
#    - In the Town
#    - Currency
#    - Zoo
#    - Expressions & Idioms associated with animals
#    - Musical Instruments
#    - Sports
#    - Hobbies
#    - Things you are in the process of doing
#    - Things you are afraid of
#    - Vacations
#    - What do you put in your suitcase?
#    - Festivals
#    - Verbs & Tenses
#    - Possessive adjectives
#    - Masculine and Feminine
#    - Singular & Plural
#    - Negation
#    - French Culture
#    - Role Play
#    - Listening, Speaking, Writing & Reading activities
#
#
# 🔹 Level: A2
#
# 📌 Topics
#    - Describe a person
#    - Qualificative Adjectives
#    - Possessive Adjectives
#    - Relative Pronouns
#    - The Heroes of Today & Earlier
#    - School
#    - Habits
#    - Ask and Give Information
#    - Social Media
#    - Connectors
#    - Irregular Verbs
#    - Compare & Classify objects and people
#    - Ask & Tell the price of something
#    - Ask & Give an opinion
#    - Express opposition
#    - Demonstrative Adjectives & Prepositions
#    - Music
#    - Shopping
#    - Narrate a Story
#    - Past Tense
#    - Express Emotions & Feelings
#    - Imperfect Tense
#    - Simple Future Tense
#    - Material Description
#    - Express an Objective
#    - Nature
#    - School Subjects
#    - Recycling
#    - Present Conditional Tense
#    - Express a wish & objective
#    - Professions
#    - Listening, Speaking, Reading & Writing Activities
#    - Alphabet & Counting
#    - Greetings
#    - Days of the Week & Months of the year
#    - Definite and indefinite articles
#    - Introduce yourself
#    - Auxiliary verbs (to be/to have)
#    - Genders (masculine/feminine)
#    - Plural form
#    - Possessive adjectives (my, your, his/her…)
#    - Regular verbs at the present tense (-er verbs)
#    - Understand and give directions
#    - Speak about the weather
#    - “on” pronoun
#    - Negation
#    - Say the time
#    - Suggest an outing
#    - Buy in shops
#    - Prepositions of location (in, on, next to, in front of…)
#    - Demonstrative adjectives (this, that)
#    - Understand a menu/Order at a restaurant
#    - Ask questions
#    - Answering a negative question
#    - Future Proche (future tense)
#    - Indicate a quantity
#    - Speak about the future
#    - Make a positive/negative comment
#    - Describe someone
#    - Reflexive verbs
#    - Imperative Form
#    - Passé Composé (past tense)
#    - Direct & Indirect pronouns
#    - Talk about your studies
#    - Give an advice, order
#    - Do your grocery shopping
#    - Contracted & Partitive articles
#    - Speak about the past
#    - Talk about a duration
#    - Présent Continu (Present continuous)
#    - Listening, Speaking, Reading & Writing Activities
#    - Speak about the sport you enjoy doing
#    - Self Introduction
#    - Give an advice
#    - Speak about your goals
#    - Express a decision
#    - Future Simple (Future tense) & Hypothesis in the future
#    - The negative imperative
#    - Express a cause/reason and a purpose
#    - Express frequency
#    - Describe your home
#    - Understand an advertisement
#    - Give directions
#    - Make a comparison & Explain a choice
#    - Present tense
#    - Prepositions
#    - Relative pronouns
#    - Comparative/Superlative
#    - Make a description
#    - Indicate a chronology
#    - Understand a biography
#    - Speak about a life-changing event
#    - Explain a problem/give solutions
#    - Le Passé composé and l’Imparfait (past tenses)
#    - « Il y a » / « Pendant »
#    - Cause, Reason, Consequence, Express a certitude & Express wishes
#    - Give an opinion
#    - How to avoid repetitions
#    - Adverbs of manner
#    - Subjonctive form
#    - Conditional Tense
#    - Irregular verbs
#    - Describe a place
#    - Ask questions about an object
#    - Describe material
#    - Indefinite adjectives (tout/toute/chaque/quelques)
#    - Opposition/Concession
#    - Interrogative & Demonstrative pronouns
#    - Gerundive form
#    - Understand a Written/ Oral advertisement
#    - Reading, Writing, Speaking & Listening activities
#
#
# 🔹 Level: B1
#
# 📌 Topics
#    - Speak about relationships
#    - Express your interest/purpose/obligation/permission
#    - Describe an accommodation
#    - Speak about your family
#    - Reflexive verbs at past tense
#    - Talk about an anecdote
#    - Indicative/Subjective
#    - Comparative/Superlative
#    - Plus-que-parfait (past tense)
#    - Place of adjectives
#    - Talk about consumption
#    - The active & passive form
#    - Adverbs
#    - Talk about cultural diversity
#    - Talk about living abroad
#    - Talk about two different events in the past
#    - Write an article
#    - Debate
#    - Future tenses
#    - Present and Past Conditional
#    - Talk about travels & Organise a trip
#    - Make an interview
#    - Talk about recycling
#    - Organize & Report a speech
#    - Make propositions to improve a city
#    - Make a complaint
#    - Gerundive & Present participle
#    - Formal questions
#    - Talk about sports and wellbeing
#    - Talk about reading & Write a biography
#    - Express your taste in art & Describe a piece of art
#    - La mise en relief (ce qui…c’est)
#    - Imagine a different past
#    - Listening Activities
#    - Speaking Activities
#    - Writing Activities
#    - Reading Activities
#
#
# 🔹 Level: B2
#
# 📌 Topics
#    - Talk about France and the French
#    - Understand a radio debate
#    - Understand a biography & a television news report
#    - Talk about learning a foreign language & anglicisms
#    - Understand a satirical drawing
#    - Declarative words
#    - Reported speech in the past
#    - Understand newspapers headlines
#    - Come to an agreement
#    - Write a short article
#    - Talk about travels
#    - Understand a movie trailer
#    - Present historical French figures
#    - React to an article
#    - Talk about health
#    - The past tenses (Passé Composé/Imparfait/Plusque-parfait)
#    - Verbal adjectives
#    - Talk about the environment/global warming
#    - Understand a TV report
#    - Talk about cooking
#    - Describe food habits
#    - Personal & Relative pronouns
#    - Talk about your impressions of France
#    - Use proverbs
#    - Write a complaint letter
#    - Compare your country to France
#    - Talk about technology, Video Games
#    - Talk about fashion
#    - Present a book
#    - Talk about your dreams
# Course Name: First Step For Kids Course in Korean
# Course Link: https://www.henryharvin.com/first-step-for-kids-course-in-korean
#
# Course Name: First Step For Kids Course in Korean
# Syllabus:
# 🔹 Module 1: Hangeul I
#    In this module, learners will get to know about the language right from the basics.
#    - Getting to know the language
#    - Alphabet
#    - Learning vowels
#    - Learning Consonants
#
#
# 🔹 Module 2: Hangeul II
#    In this module, students will get to know about the language right from basics.
#    - Getting to know about language.
#    - Pronunciation of Batchim
#    - Greetings
#
#
# 🔹 Module 3: Introduction
#    This module have the student to get through the basics knowledge of Korea.
#    - Introduction to Korea
#
#
# 🔹 Module 4: Human Body Parts
#    This module will help students to know about the body parts in human beings.
#    - Body Parts
#
#
# 🔹 Module 5: Colours name
#    This module will help the candidate to learn name of colours in Korean.
#    - Name of Colours
#
#
# 🔹 Module 6: Professions
#    This module will help the candidate to make learn about the different proffesion names.
#    - Profession Name
#
#
# 🔹 Module 7: Name of Animals & birds
#    This module will help the candidate to learn the name of animals & birds in korean.
#    - Animals & Bird
#
#
# 🔹 Module 8: Foods
#    This module will help the candidate to know food vocabulary.
#    - Food vocabs / Ingredients
#
#
# 🔹 Module 9: Insects
#    This module will help the candidate to learn the name of insects.
#    - Insects
#
#
# 🔹 Module 10: Shopping Vocabulary
#    In this module, candidate will know about other essential items of daily life.
#    - Shopping
#
#
# 🔹 Module 11: Family Related Name
#    This module will enhance students to know all the name the family members.
#    - Family Members
#
#
# 🔹 Module 12: Police : Lost & Found
#    In this module, learners will get to know how to use vocabs related to police.
#    - Police related Vocabs
#
#
# 🔹 Module 13: Sports
#    In this module, learners will get to know how to use vocabs related to sports.
#    - Sports
#
#
# 🔹 Module 14: Numerals
#    This module will make students learn about Pure and Sino Numerals. (Money, time, Date etc.)
#    - Sino & Pure Numerals
#
#
# 🔹 Module 15: Time
#    In this module, learners will get to know how to use numbers in different ways.
#    - Time
#
#
# 🔹 Module 16: Weekdays
#    In this module, learners will get to know the name of the weekdays.
#    - Weekdays
# Course Name: Not Found
# Course Link: https://learner.henryharvin.com/explore-free-course-auth
#
# Course Name: Not Found
# Syllabus:
# Syllabus not available
# Course Name: Not Found
# Course Link: https://www.henryharvin.com/our-courses
#
# Course Name: Not Found
# Syllabus:
# Syllabus not available
# Course Name: Not Found
# Course Link: https://ecommerce.henryharvin.com/certification
#
# Course Name: Not Found
# Syllabus:
# Syllabus not available
# Course Name: College Training
# Course Link: https://www.henryharvin.com/college-trainings
#
# Course Name: College Training
# Syllabus:
# Syllabus not available
# Course Name: Henry Harvin Education
# Course Link: https://www.coursereport.com/schools/henry-harvin-education
#
# Course Name: Henry Harvin Education
# Syllabus:
# Syllabus not available
# Course Name: Job Guarantee Program Terms and Conditions
# Course Link: https://www.henryharvin.com/job-guarantee-program-terms-and-conditions
#
# Course Name: Job Guarantee Program Terms and Conditions
# Syllabus:
# Syllabus not available
# Data saved to C:\Users\taslim.siddiqui\Downloads\HENRY_Raghu.xlsx

# %% [markdown]
# EXTRACT COURSE NAME CERTIFIACTE IMAGE FORM COURSE LINK DIRECT

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import pandas as pd
from bs4 import BeautifulSoup
import time

def get_driver():
    options = uc.ChromeOptions()
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--window-size=1280,720")
    options.add_argument("--log-level=3")
    return uc.Chrome(options=options, version_main=138)

def clean_text(text):
    """Clean and normalize text"""
    if text:
        text = ' '.join(text.split())  # Remove extra whitespace
        text = text.replace('\xa0', ' ')  # Replace non-breaking spaces
        text = text.replace('"', "'")  # Normalize quotes
    return text.strip() if text else ""

def extract_certificate_image(soup):
    """Extract certificate image URL from the page"""
    certificate_div = soup.find("div", id=lambda x: x and "cerificate" in x.lower())
    if certificate_div:
        img_tag = certificate_div.find("img")
        if img_tag and "src" in img_tag.attrs:
            return img_tag["src"]
    return "Certificate image not found"

def extract_syllabus(soup):
    syllabus = []
    curriculum_div = soup.find("div", id="curriculum")
    
    if curriculum_div:
        modules = curriculum_div.find_all("li", class_="bg-white my-2 shadow-lg")
        
        for module in modules:
            # Extract module title
            title_span = module.find("span")
            if title_span:
                module_title = clean_text(title_span.get_text())
                syllabus.append(f"\n🔹 {module_title}\n")
            
            # Extract module content
            content_div = module.find("div", class_="mx-6 pl-6")
            if content_div:
                current_element = content_div.find_next()
                while current_element and current_element.name:
                    if current_element.name == "p":
                        strong = current_element.find("strong")
                        if strong:
                            strong_text = clean_text(strong.get_text())
                            syllabus.append(f"\n📌 {strong_text}\n")
                            remaining_text = clean_text(current_element.text.replace(strong.text, ""))
                            if remaining_text:
                                syllabus.append(f"   {remaining_text}\n")
                        else:
                            text = clean_text(current_element.get_text())
                            if text:
                                syllabus.append(f"   {text}\n")
                    elif current_element.name == "ul":
                        for li in current_element.find_all("li"):
                            li_text = clean_text(li.get_text())
                            if li_text:
                                syllabus.append(f"   - {li_text}\n")
                    elif current_element.string and current_element.string.strip():  # Plain text nodes
                        text = clean_text(current_element.string)
                        if text:
                            syllabus.append(f"   {text}\n")
                    
                    current_element = current_element.find_next_sibling()
            
            syllabus.append("\n")  # Extra line between modules
    
    return ''.join(syllabus).strip() if syllabus else "Syllabus not available"

def extract_course_data(url):
    driver = None
    try:
        driver = get_driver()
        driver.get(url)
        
        # Wait for page to load
        time.sleep(5)
        
        # Scroll to trigger content loading
        for _ in range(3):
            driver.execute_script("window.scrollBy(0, 500)")
            time.sleep(1)
        
        # Get page source for BeautifulSoup
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')
        
        # Extract course name
        course_name = "Not Found"
        try:
            course_name = clean_text(soup.find("h1").get_text())
        except:
            pass
        
        # Extract about course
        about_course = "Not Found"
        try:
            about_div = soup.find("div", class_="font-ad")
            if about_div:
                about_paragraph = about_div.find("p")
                if about_paragraph:
                    about_course = clean_text(about_paragraph.get_text())
        except:
            pass
        
        # Extract syllabus
        syllabus = extract_syllabus(soup)
        
        # Extract certificate image
        certificate_image = extract_certificate_image(soup)
        
        return {
            'Course Name': course_name,
            'About Course': about_course,
            'Syllabus': syllabus,
            'Certificate Image URL': certificate_image,
            'URL': url
        }
        
    except Exception as e:
        print(f"Error occurred: {str(e)}")
        return {
            'Course Name': 'Error',
            'About Course': 'Error',
            'Syllabus': 'Error',
            'Certificate Image URL': 'Error',
            'URL': url
        }
    finally:
        if driver:
            driver.quit()

def save_to_excel(data, filename="course_data1.xlsx"):
    # Create DataFrame with the data
    df = pd.DataFrame([data])
    
    try:
        # Try to read existing file
        existing_df = pd.read_excel(filename)
        # Check if URL already exists to prevent duplicates
        if data['URL'] not in existing_df['URL'].values:
            updated_df = pd.concat([existing_df, df], ignore_index=True)
            updated_df.to_excel(filename, index=False)
            print(f"Data appended to {filename}")
        else:
            print(f"Data for {data['URL']} already exists in {filename}")
    except FileNotFoundError:
        # If file doesn't exist, create new one
        df.to_excel(filename, index=False)
        print(f"New file {filename} created")

# List of course URLs to scrape
urls = [
    "https://www.henryharvin.com/banking-law-course",
    "https://www.henryharvin.com/french-language-course",
    # Add more URLs here
]

for url in urls:
    print(f"\nScraping: {url}")
    course_data = extract_course_data(url)
    print(f"Course Name: {course_data['Course Name']}")
    save_to_excel(course_data)
    print("---")
# Out:
# Scraping: https://www.henryharvin.com/banking-law-course
# Course Name: Banking Law Course
# New file course_data1.xlsx created
# ---
#
# Scraping: https://www.henryharvin.com/french-language-course
# Course Name: French Language Course
# Data appended to course_data1.xlsx
# ---
